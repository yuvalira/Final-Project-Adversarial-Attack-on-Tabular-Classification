# %% [markdown]
# <a href="https://colab.research.google.com/github/yuvalira/Final-Project-Adversarial-Attack-on-Tabular-Classification/blob/main/ATTACK/Attack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# System and file handling
import os
import pickle
import joblib

# Data processing and manipulation
import numpy as np
import pandas as pd
from random import sample
from scipy.stats import pointbiserialr
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Evaluation metrics
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_curve,
    roc_auc_score
)
from sklearn.manifold import TSNE

# Transformers and model loading
import torch
from transformers import RobertaTokenizer, RobertaForMaskedLM
from huggingface_hub import hf_hub_download

# Visualization
import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrowPatch
import matplotlib.patheffects as pe
from matplotlib.lines import Line2D

# %% [markdown]
# # **1. Model and Dataset Setup**

# %% [markdown]
# ### 1.1 Load pretrained GBT model and label encoders from GitHub repository

# %%
# Git clone
REPO_URL = "https://github.com/yuvalira/Final-Project-Adversarial-Attack-on-Tabular-Classification.git"
# !git clone {REPO_URL}
# %cd Final-Project-Adversarial-Attack-on-Tabular-Classification

# Read GBT model (sklearn)
model_path = 'GBT/sklearn_GBT_model.joblib'
assert os.path.exists(model_path), f"Model file not found at {model_path}"
model_gbt = joblib.load(model_path)
print("sklearn GBT model loaded successfully.")

# Load label encoders for decoding categorical features
with open('data/label_encoders.pkl', 'rb') as f:
    encoders = pickle.load(f)
print("Label encoders loaded successfully.")
# Out:
# Cloning into 'Final-Project-Adversarial-Attack-on-Tabular-Classification'...
# remote: Enumerating objects: 334, done.
# remote: Counting objects: 100% (166/166), done.
# remote: Compressing objects: 100% (148/148), done.
# remote: Total 334 (delta 82), reused 21 (delta 18), pack-reused 168 (from 1)
# Receiving objects: 100% (334/334), 8.65 MiB | 14.97 MiB/s, done.
# Resolving deltas: 100% (141/141), done.
# /content/Final-Project-Adversarial-Attack-on-Tabular-Classification
# sklearn GBT model loaded successfully.
# Label encoders loaded successfully.

# %% [markdown]
# ### 1.2 Load attack input dataset from Hugging Face Hub
# Download the experiment_data.csv file, which serves as the input for adversarial attacks

# %%
csv_path = hf_hub_download(
    repo_id="ETdanR/Balanced_Adult_Split_DS",
    filename="experiment_data.csv",
    repo_type="dataset"
)
experiment_data = pd.read_csv(csv_path)
# Out:
# experiment_data.csv:   0%|          | 0.00/924k [00:00<?, ?B/s]

# %% [markdown]
# ### 1.3 Load fine-tuned RoBERTa model and tokenizer for masked income prediction

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load fine-tuned model directly from Hugging Face Hub
model_path = "ETdanR/RoBERTa_FT_adult"  # model repo
tokenizer = RobertaTokenizer.from_pretrained(model_path)
model = RobertaForMaskedLM.from_pretrained(model_path)
model.eval()
model.to(device)

# Define mask token info
mask_token = tokenizer.mask_token
mask_token_id = tokenizer.mask_token_id

# Token IDs for income prediction (example IDs from your snippet)
greater_than_id = 9312  # "Greater"
less_than_id = 10862    # "Less"

# %% [markdown]
# # **2. Prediction Functions**

# %% [markdown]
# ### 2.1 predict_GBT
# Predicts class labels using a trained GBT model.
# Automatically applies label encoding to categorical string features if needed.

# %%
def predict_GBT(input_df: pd.DataFrame) -> tuple[np.ndarray, np.ndarray]:
    """
    Makes predictions using the loaded GBT model, handling label encoding for
    categorical features.
    Args: input_df (pd.DataFrame): DataFrame containing the features for prediction.
                                 Can contain string categorical values.
    Returns: Tuple: Predicted class labels (0 or 1), Confidence scores (probability of class 1, i.e., > 50K)
    """
    # Create a copy of the input to avoid modifying the original DataFrame
    processed_df = input_df.copy()

    # Apply label encoding to each categorical feature using the saved encoders
    for feature in categorical_features:
        if feature in processed_df.columns and feature in encoders:
            le = encoders[feature]
            try:
                # Transform known categories
                processed_df[feature] = le.transform(processed_df[feature])
            except ValueError as e:
                # Handle unseen categories by mapping them to 0 (first known class)
                print(f"Warning: Could not transform feature '{feature}' due to unknown category. Error: {e}")

                unknown_cats = processed_df[feature][~processed_df[feature].isin(le.classes_)]
                if not unknown_cats.empty:
                    print(f"Mapping unknown categories {unknown_cats.unique().tolist()} in '{feature}' to 0 (first class).")
                    processed_df[feature] = processed_df[feature].apply(
                        lambda x: le.transform([x])[0] if x in le.classes_ else 0
                    )

    # Get predicted class labels
    predictions = model_gbt.predict(processed_df)

    # Get probabilities of class 1 (i.e., > 50K)
    probabilities = model_gbt.predict_proba(processed_df)[:, 1]

    return predictions, probabilities

# %% [markdown]
# ### 2.2 Predict LLM
# Generate predictions using the fine-tuned RoBERTa language model.
# Converts each input row into a pseudo-sentence with a masked income token, performs batched inference, and maps predicted tokens to class labels.

# %%
def predict_LM(df: pd.DataFrame):
    """
    Generates predictions for a DataFrame of input features using a Language Model.
    Args: df (pd.DataFrame): DataFrame with tabular features per row.
    Returns: np.ndarray: Array of predictions (0 for <=50K, 1 for >50K, -1 for unknown).
    """

    # Check if model and tokenizer are loaded
    if tokenizer is None or model is None:
        print("Error: Hugging Face tokenizer or model not loaded. Returning random predictions.")
        random_preds = np.random.randint(0, 2, size=len(df))
        random_scores = np.random.rand(len(df))
        return random_preds, random_scores

    # Convert each row into a pseudo-sentence with a masked income token
    sentences = []
    for _, row in df.iterrows():
        sentence_parts = [
            f"age: {row['age']}",
            f"workclass: {row['workclass']}",
            f"education: {row['education']}",
            f"educational-num: {row['educational-num']}",
            f"marital-status: {row['marital-status']}",
            f"occupation: {row['occupation']}",
            f"relationship: {row['relationship']}",
            f"race: {row['race']}",
            f"gender: {row['gender']}",
            f"capital-gain: {row['capital-gain']}",
            f"capital-loss: {row['capital-loss']}",
            f"hours-per-week: {row['hours-per-week']}",
            f"native-country: {row['native-country']}"
        ]
        sentence_parts.append(f"income: {mask_token} than 50k")
        sentences.append(", ".join(sentence_parts))

    # Tokenize sentences and move tensors to device
    encoded = tokenizer(
        sentences,
        return_tensors='pt',
        padding=True,
        truncation=True,
        max_length=128
    ).to(device)

    # Run the model to get logits (no gradient calculation)
    with torch.no_grad():
        outputs = model(**encoded)
        logits = outputs.logits

    # Locate the positions of mask tokens in the input
    mask_batch_indices, mask_token_indices = (encoded['input_ids'] == mask_token_id).nonzero(as_tuple=True)

    # Initialize result arrays
    pred_tensor = torch.full((len(df),), -1, dtype=torch.long, device=device)
    score_tensor = torch.full((len(df),), -1.0, dtype=torch.float, device=device)

    if mask_batch_indices.numel() > 0:
        # Extract logits at masked positions
        logits_at_mask = logits[mask_batch_indices, mask_token_indices]
        probs = torch.softmax(logits_at_mask, dim=-1)

        # Predict token IDs at mask and map to classes
        predicted_token_ids_at_mask = torch.argmax(logits_at_mask, dim=-1)
        is_greater = (predicted_token_ids_at_mask == greater_than_id)
        is_less = (predicted_token_ids_at_mask == less_than_id)

        mapped_predictions = torch.full_like(predicted_token_ids_at_mask, -1)
        mapped_predictions[is_greater] = 1
        mapped_predictions[is_less] = 0

        # Assign predictions to the correct batch positions
        pred_tensor[mask_batch_indices] = mapped_predictions
        score_tensor[mask_batch_indices] = probs[:, greater_than_id]

    # Return predictions and scores as NumPy arrays
    return pred_tensor.cpu().numpy(), score_tensor.cpu().numpy()

# %% [markdown]
# # **3. Guassian Perturb and Minimize Attack**

# %% [markdown]
# ## 3.1 Helper Functions

# %% [markdown]
# ### Extract batch
# Extract a batch for the algorithm. Keep position to move consecutivly.

# %%
def extract_batch(df, batch_length, last_row_handled):
    start = last_row_handled # Start index of the current batch

    # If all rows have been handled, return None
    if start >= len(df):
        return None, None

    end = min(start + batch_length, len(df))  # End index of the batch

    # Extract batch from DataFrame
    batch = df.iloc[start:end]

    # Update the last handled row index
    new_last_row_handled = end

    return batch, new_last_row_handled

# %% [markdown]
# ### Categorical gaussian perturb
# Use Guassian sampeling to perturb categorical features

# %%
def categorical_gaussian_perturb(datapoint, correlation_dict, sigmas, categorical_features):
    """
    Applies Gaussian-based perturbation to categorical features based on correlation scores.
    """

    # Create a copy to avoid modifying the original input
    perturbed_datapoint = datapoint.copy()

    # Iterate over all features
    for feature in datapoint.columns:
        # Only perturb categorical features
        if feature not in categorical_features:
            continue

        # Current value of the feature
        current_value = datapoint[feature].iloc[0]
        category_scores = correlation_dict[feature]
        categories = list(category_scores.keys())

        # Get correlation score positions
        positions = np.array([category_scores[cat] for cat in categories])
        center = category_scores[current_value]

        # Standard deviation for this feature
        feature_sigma = sigmas[feature]

        # Compute Gaussian weights based on correlation distance
        distances = positions - center
        weights = np.exp(-0.5 * (distances / feature_sigma) ** 2)
        weights /= weights.sum()

        # Sample new category based on weights
        sampled_index = np.random.choice(len(categories), p=weights)
        new_value = categories[sampled_index]

        # Update the feature with the new value
        perturbed_datapoint[feature] = new_value

    return perturbed_datapoint

# %% [markdown]
# ### Numerical gaussian perturb
# Use Guassian sampling to perturb numerical features

# %%
def numerical_gaussian_perturb(datapoint, correlation_dict, sigmas, numerical_features):
    """
    Applies Gaussian-based perturbation to numerical features based on correlation distance.
    """

    # Copy to avoid modifying the original input
    perturbed_datapoint = datapoint.copy()

    # Iterate over all features
    for feature in datapoint.columns:
        # Only perturb numerical features
        if feature not in numerical_features:
            continue

        current_value = datapoint[feature].iloc[0] # Current numerical value

        # Possible values based on correlation dictionary
        possible_values = [float(val) for val in correlation_dict[feature].keys()]
        positions = np.array(possible_values)
        center = current_value

        # Standard deviation for this feature
        feature_sigma = sigmas[feature]

        # Compute Gaussian weights
        distances = positions - center
        weights = np.exp(-0.5 * (distances / feature_sigma) ** 2)
        weights /= weights.sum()

        # Sample new value using the computed weights
        sampled_value = np.random.choice(possible_values, p=weights, size=1)[0]

        # Update feature with the sampled value
        perturbed_datapoint[feature] = sampled_value

    return perturbed_datapoint

# %% [markdown]
# ### Minimize features

# %% [markdown]
# Finds the feature with the highest correlation-based deviation from the original sample.

# %%
def find_feature_to_minimize(current_dp, original_dp, correlation_dict, saturated_features):
    max_score_diff = -float('inf')
    feature_to_minimize = None

    for feature in current_dp.columns:
        if feature in saturated_features:
            continue

        # get features
        current_val = current_dp.iloc[0][feature]
        original_val = original_dp.iloc[0][feature]

        # Get correlation scores
        current_score = correlation_dict[feature].get(current_val, 0.0)
        original_score = correlation_dict[feature].get(original_val, 0.0)

        score_diff = abs(original_score - current_score)

        if score_diff > max_score_diff:
            max_score_diff = score_diff
            feature_to_minimize = feature

    return feature_to_minimize

# %% [markdown]
# This function updates the selected feature by taking one step toward its original value, based on the ordering of correlation scores.

# %%
def minimize_feature(current_dp, feature, correlation_dict, original_dp):
    # Get current and original values
    current_val = current_dp.iloc[0][feature]
    original_val = original_dp.iloc[0][feature]

    # Sort feature values by correlation score
    ordered_values = list(correlation_dict[feature].keys())

    current_index = ordered_values.index(current_val)
    original_index = ordered_values.index(original_val)

    # Step one position toward the original
    sign = (original_index - current_index) // abs(original_index - current_index)
    new_index = current_index + sign

    new_val = ordered_values[new_index]
    current_dp.loc[current_dp.index[0], feature] = new_val
    return current_dp

# %% [markdown]
# ### Correlation dictionary

# %%
# Define feature groups
numerical_features = ['age', 'educational-num', 'capital-gain', 'capital-loss', 'hours-per-week']
categorical_features = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'native-country']

# Copy the original dataset
df = experiment_data.copy()

# Create binary target label (1 for >50K, 0 otherwise)
df['income_binary'] = df['income'].apply(lambda x: 1 if '>50K' in x else 0)

# Separate target and input features
target = df['income_binary']
features_main = df.drop(columns=['income', 'income_binary'])

# Initialize correlation dictionary
correlation_dict = {}

# Compute point-biserial correlation for each value in each feature
for col in features_main.columns:
    value_corrs = {}

    if df[col].dtype == 'object':
        # For categorical features: compute correlation for each category
        for val in df[col].unique():
            binary_vec = df[col].apply(lambda x: 1 if x == val else 0)
            corr, _ = pointbiserialr(binary_vec, target)
            value_corrs[val] = float(corr if pd.notnull(corr) else 0)
    else:
        # For numerical features: treat each value as a separate binary indicator
        for val in sorted(df[col].unique()):
            binary_vec = df[col].apply(lambda x: 1 if x == val else 0)
            corr, _ = pointbiserialr(binary_vec, target)
            value_corrs[int(val)] = float(corr if pd.notnull(corr) else 0)

    # Sort values: categorical by descending correlation, numerical by value
    if col in categorical_features:
        correlation_dict[col] = dict(sorted(value_corrs.items(), key=lambda x: x[1], reverse=True))
    else:
        correlation_dict[col] = dict(sorted(value_corrs.items(), key=lambda x: x[0]))

# Print correlation scores for each feature and value
for feature, value_corrs in correlation_dict.items():
    print(f"\nFeature: {feature}")
    for val, corr in value_corrs.items():
        print(f"  {val} → {corr:.3f}")
# Out:
# Feature: age
#   17 → -0.077
#   18 → -0.102
#   19 → -0.116
#   20 → -0.123
#   21 → -0.107
#   22 → -0.112
#   23 → -0.122
#   24 → -0.095
#   25 → -0.086
#   26 → -0.081
#   27 → -0.072
#   28 → -0.045
#   29 → -0.043
#   30 → -0.020
#   31 → -0.016
#   32 → -0.011
#   33 → -0.008
#   34 → 0.025
#   35 → 0.006
#   36 → 0.018
#   37 → 0.029
#   38 → 0.018
#   39 → 0.050
#   40 → 0.029
#   41 → 0.036
#   42 → 0.054
#   43 → 0.058
#   44 → 0.044
#   45 → 0.038
#   46 → 0.054
#   47 → 0.067
#   48 → 0.067
#   49 → 0.039
#   50 → 0.054
#   51 → 0.038
#   52 → 0.057
#   53 → 0.048
#   54 → 0.050
#   55 → 0.028
#   56 → 0.014
#   57 → 0.020
#   58 → 0.035
#   59 → 0.020
#   60 → 0.008
#   61 → 0.025
#   62 → 0.028
#   63 → 0.007
#   64 → 0.016
#   65 → 0.017
#   66 → 0.002
#   67 → -0.005
#   68 → 0.000
#   69 → -0.013
#   70 → -0.013
#   71 → -0.018
#   72 → -0.021
#   73 → -0.023
#   74 → -0.010
#   75 → 0.004
#   76 → -0.018
#   77 → -0.014
#   78 → -0.000
#   79 → 0.006
#   80 → -0.014
#   81 → -0.011
#   82 → -0.015
#   85 → -0.000
#   86 → -0.011
#   90 → -0.004
#
# Feature: workclass
#   Self-emp-inc → 0.129
#   Federal-gov → 0.081
#   Local-gov → 0.049
#   Self-emp-not-inc → 0.025
#   State-gov → 0.017
#   Without-pay → -0.015
#   Private → -0.147
#
# Feature: education
#   Bachelors → 0.189
#   Masters → 0.164
#   Prof-school → 0.136
#   Doctorate → 0.116
#   Assoc-acdm → -0.000
#   Assoc-voc → -0.008
#   Preschool → -0.022
#   1st-4th → -0.052
#   5th-6th → -0.058
#   12th → -0.060
#   Some-college → -0.069
#   7th-8th → -0.071
#   9th → -0.080
#   10th → -0.103
#   11th → -0.114
#   HS-grad → -0.145
#
# Feature: educational-num
#   1 → -0.022
#   2 → -0.052
#   3 → -0.058
#   4 → -0.071
#   5 → -0.080
#   6 → -0.103
#   7 → -0.114
#   8 → -0.060
#   9 → -0.145
#   10 → -0.069
#   11 → -0.008
#   12 → -0.000
#   13 → 0.189
#   14 → 0.164
#   15 → 0.136
#   16 → 0.116
#
# Feature: marital-status
#   Married-civ-spouse → 0.525
#   Married-AF-spouse → 0.012
#   Married-spouse-absent → -0.035
#   Widowed → -0.081
#   Separated → -0.105
#   Divorced → -0.175
#   Never-married → -0.404
#
# Feature: occupation
#   Exec-managerial → 0.215
#   Prof-specialty → 0.185
#   Protective-serv → 0.036
#   Tech-support → 0.032
#   Sales → 0.020
#   Armed-Forces → -0.000
#   Transport-moving → -0.013
#   Craft-repair → -0.044
#   Priv-house-serv → -0.046
#   Farming-fishing → -0.068
#   Machine-op-inspct → -0.096
#   Adm-clerical → -0.119
#   Handlers-cleaners → -0.119
#   Other-service → -0.218
#
# Feature: relationship
#   Husband → 0.452
#   Wife → 0.137
#   Other-relative → -0.120
#   Unmarried → -0.192
#   Not-in-family → -0.251
#   Own-child → -0.295
#
# Feature: race
#   White → 0.109
#   Asian-Pac-Islander → 0.016
#   Other → -0.031
#   Amer-Indian-Eskimo → -0.042
#   Black → -0.121
#
# Feature: gender
#   Male → 0.254
#   Female → -0.254
#
# Feature: capital-gain
#   0 → -0.252
#   594 → -0.026
#   914 → -0.015
#   991 → -0.011
#   1055 → -0.030
#   1086 → -0.011
#   1151 → -0.011
#   1173 → -0.011
#   1409 → -0.011
#   1424 → -0.011
#   1455 → -0.011
#   1506 → -0.021
#   1797 → -0.011
#   1831 → -0.011
#   1848 → -0.011
#   2050 → -0.011
#   2105 → -0.015
#   2174 → -0.032
#   2176 → -0.011
#   2202 → -0.021
#   2290 → -0.015
#   2329 → -0.011
#   2354 → -0.018
#   2407 → -0.024
#   2414 → -0.011
#   2463 → -0.015
#   2580 → -0.024
#   2597 → -0.024
#   2635 → -0.021
#   2653 → -0.021
#   2829 → -0.028
#   2885 → -0.018
#   2907 → -0.024
#   2936 → -0.011
#   2961 → -0.011
#   2977 → -0.015
#   3103 → 0.079
#   3137 → -0.021
#   3273 → -0.011
#   3325 → -0.028
#   3411 → -0.024
#   3464 → -0.028
#   3471 → -0.011
#   3674 → -0.011
#   3781 → -0.018
#   3887 → -0.011
#   3908 → -0.015
#   3942 → -0.015
#   4064 → -0.033
#   4101 → -0.021
#   4386 → 0.061
#   4416 → -0.018
#   4508 → -0.011
#   4650 → -0.028
#   4687 → 0.018
#   4787 → 0.042
#   4865 → -0.021
#   4931 → -0.011
#   4934 → 0.024
#   5013 → -0.038
#   5178 → 0.081
#   5455 → -0.015
#   5556 → 0.015
#   6097 → 0.011
#   6418 → 0.028
#   6497 → -0.015
#   6514 → 0.018
#   6849 → -0.030
#   7298 → 0.133
#   7430 → 0.030
#   7688 → 0.126
#   7896 → 0.011
#   8614 → 0.060
#   9386 → 0.033
#   9562 → 0.015
#   10520 → 0.046
#   10605 → 0.026
#   11678 → 0.011
#   13550 → 0.037
#   14084 → 0.051
#   14344 → 0.040
#   15020 → 0.026
#   15024 → 0.147
#   15831 → 0.024
#   18481 → 0.011
#   20051 → 0.038
#   22040 → -0.011
#   25124 → 0.011
#   25236 → 0.026
#   27828 → 0.048
#   99999 → 0.098
#
# Feature: capital-loss
#   0 → -0.142
#   213 → -0.011
#   625 → -0.015
#   653 → 0.015
#   880 → -0.011
#   1092 → -0.015
#   1138 → -0.011
#   1408 → -0.015
#   1429 → -0.011
#   1485 → 0.029
#   1504 → -0.024
#   1564 → 0.042
#   1579 → -0.021
#   1590 → -0.030
#   1594 → -0.011
#   1602 → -0.024
#   1617 → -0.018
#   1628 → -0.018
#   1651 → -0.011
#   1669 → -0.024
#   1672 → -0.021
#   1719 → -0.015
#   1721 → -0.018
#   1726 → -0.011
#   1740 → -0.030
#   1741 → -0.026
#   1755 → 0.011
#   1762 → -0.015
#   1825 → 0.011
#   1848 → 0.054
#   1876 → -0.028
#   1887 → 0.100
#   1902 → 0.113
#   1911 → 0.011
#   1974 → -0.021
#   1977 → 0.102
#   1980 → -0.032
#   2001 → -0.011
#   2002 → -0.011
#   2042 → -0.015
#   2051 → -0.021
#   2057 → -0.015
#   2174 → 0.015
#   2179 → -0.021
#   2205 → -0.011
#   2206 → -0.011
#   2246 → 0.018
#   2258 → 0.009
#   2339 → -0.024
#   2377 → 0.005
#   2392 → 0.015
#   2415 → 0.061
#   2444 → 0.024
#   2467 → -0.011
#   2547 → 0.018
#   2559 → 0.030
#   2603 → -0.011
#   2824 → 0.021
#   3004 → 0.015
#   3900 → -0.011
#
# Feature: hours-per-week
#   1 → -0.015
#   2 → -0.012
#   3 → 0.011
#   4 → -0.021
#   5 → 0.012
#   6 → -0.014
#   7 → 0.006
#   8 → -0.029
#   9 → -0.021
#   10 → -0.049
#   11 → -0.024
#   12 → -0.036
#   13 → -0.015
#   14 → -0.011
#   15 → -0.056
#   16 → -0.051
#   17 → -0.027
#   18 → -0.032
#   19 → -0.024
#   20 → -0.111
#   21 → -0.012
#   22 → -0.012
#   23 → -0.021
#   24 → -0.052
#   25 → -0.083
#   26 → -0.014
#   27 → -0.024
#   28 → -0.025
#   30 → -0.099
#   32 → -0.043
#   33 → -0.020
#   34 → -0.024
#   35 → -0.061
#   36 → -0.014
#   37 → -0.019
#   38 → -0.003
#   39 → -0.004
#   40 → -0.080
#   41 → 0.008
#   42 → 0.022
#   43 → 0.008
#   44 → 0.019
#   45 → 0.078
#   46 → -0.004
#   47 → 0.011
#   48 → 0.034
#   49 → -0.004
#   50 → 0.152
#   51 → -0.005
#   52 → 0.020
#   53 → -0.012
#   54 → 0.006
#   55 → 0.079
#   56 → 0.002
#   57 → 0.020
#   58 → -0.003
#   60 → 0.109
#   61 → 0.018
#   62 → 0.000
#   63 → 0.005
#   64 → -0.000
#   65 → 0.032
#   66 → -0.015
#   67 → -0.000
#   68 → 0.015
#   69 → 0.011
#   70 → 0.035
#   72 → 0.013
#   73 → -0.000
#   74 → 0.011
#   75 → -0.006
#   76 → 0.011
#   77 → -0.018
#   78 → 0.000
#   80 → 0.024
#   81 → -0.011
#   84 → 0.022
#   85 → 0.017
#   86 → 0.006
#   89 → -0.011
#   90 → 0.022
#   92 → 0.011
#   96 → -0.006
#   97 → -0.011
#   98 → 0.000
#   99 → 0.022
#
# Feature: native-country
#   United-States → 0.046
#   France → 0.020
#   Germany → 0.020
#   Canada → 0.017
#   Philippines → 0.017
#   Italy → 0.015
#   Yugoslavia → 0.014
#   Iran → 0.013
#   China → 0.011
#   Japan → 0.009
#   India → 0.008
#   Ecuador → 0.006
#   Taiwan → 0.006
#   Ireland → 0.004
#   Greece → 0.004
#   South → 0.003
#   England → 0.002
#   Cuba → 0.000
#   Cambodia → -0.004
#   Laos → -0.005
#   Poland → -0.006
#   Scotland → -0.006
#   Trinadad&Tobago → -0.006
#   Hong → -0.006
#   Portugal → -0.007
#   Thailand → -0.009
#   Haiti → -0.010
#   Hungary → -0.015
#   Outlying-US(Guam-USVI-etc) → -0.015
#   Vietnam → -0.017
#   Puerto-Rico → -0.018
#   Jamaica → -0.018
#   El-Salvador → -0.021
#   Dominican-Republic → -0.022
#   Guatemala → -0.022
#   Nicaragua → -0.022
#   Columbia → -0.033
#   Peru → -0.035
#   Mexico → -0.084

# %% [markdown]
# ### Distance Metrics for Perturbed Samples
# Compute correlation-based distance between original and modified samples

# %%
def batch_distance_score(batch_original, batch_minimized, correlation_dict):

    total_squared_diffs = []

    for i in range(len(batch_original)):
        original_dp = batch_original.iloc[[i]]
        minimized_dp = batch_minimized.iloc[[i]]

        squared_diffs_per_dp = []

        for feature in batch_minimized.columns:
            original_val = original_dp.at[original_dp.index[0], feature]
            minimized_val = minimized_dp.at[minimized_dp.index[0], feature]

            original_corr_score = correlation_dict[feature].get(original_val, 0.0)
            minimized_corr_score = correlation_dict[feature].get(minimized_val, 0.0)

            # Calculate squared absolute difference
            squared_diff = abs(original_corr_score - minimized_corr_score)**2
            squared_diffs_per_dp.append(squared_diff)


        total_squared_diff_dp = np.sum(squared_diffs_per_dp)
        distance_for_dp = np.sqrt(total_squared_diff_dp)
        total_squared_diffs.append(distance_for_dp)


    # Average score across all datapoints
    average_score_across_datapoints = np.mean(total_squared_diffs)

    return average_score_across_datapoints

# %% [markdown]
# ## 3.2 Correlation-Guided Adversarial Attack
#
# This function performs a correlation-guided adversarial attack on tabular data, combining perturbation and minimization:
#
# 1. **Perturbation Phase**:
#    - Iteratively applies random Gaussian-based perturbations to both categorical and numerical features.
#    - Perturbation is guided by a correlation dictionary: categories or values closer (in correlation) to the original are sampled with higher probability.
#    - After each iteration, predictions are checked.
#    - Only samples that were originally correct and became misclassified are kept; the rest are reset.
#
# 2. **Minimization Phase**:
#    - For each adversarial (flipped) sample, the algorithm identifies the feature with the largest correlation difference from the original.
#    - That feature is moved one step toward its original value (based on correlation ordering).
#    - If the minimization reverts the prediction back to correct, the step is undone and the feature is marked as saturated.
#    - The process continues until all features are saturated or until a max iteration count is reached.
#
# This approach generates adversarial examples that are both effective and minimally perturbed in correlation space.

# %%
def generate_adversarial_dataset(
    df,
    modelArch,  # "LM" for predict_LM, "GBT" for predict_GBT
    correlation_dict,
    sigmas,
    numerical_features,
    categorical_features,
    num_perturb_iterations,
    num_minimize_iterations,
    batch_size: int = 32,
    random_seed = 42
):
    # Set random seed for reproducibility
    np.random.seed(random_seed)

    # Initialize state variables
    last_row_handled = 0
    total_rows = len(df)
    all_adversarial_batches = []
    all_perturbation_accuracies = []
    all_minimization_distances = []
    batch_sizes = []

    # Process the dataset in batches
    while last_row_handled < total_rows:
        print(f"\n--- Processing batch starting from row {last_row_handled} ---")

        # Extract current batch
        true_batch, last_row_handled = extract_batch(df, batch_size, last_row_handled)
        batch = true_batch.copy()
        batch_sizes.append(len(batch))

        # Get true labels and prepare input features
        true_labels = true_batch['income'].apply(lambda x: 1 if x.strip() == '>50K' else 0).to_numpy()
        batch.drop(columns=['income'], inplace=True)
        batch.drop(columns=['income_binary'], inplace=True)

        # Get initial predictions
        current_labels, original_scores = predict_LM(batch) if modelArch == "LM" else predict_GBT(batch)
        original_predictions = current_labels.copy()
        original_incorrect_predictions = (original_predictions != true_labels)

        # -------------------------------------------------------------------------------
        #                               Perturbation Loop
        # -------------------------------------------------------------------------------
        print(f"Original accuracy: {sum(current_labels==true_labels)/len(batch)}")

        perturbation_accuracies = []

        for perturb_iteration in range(num_perturb_iterations):
            # Record accuracy before perturbation
            acc = sum(current_labels == true_labels) / len(batch)
            perturbation_accuracies.append(acc)

            # Apply perturbations to correctly classified samples
            for index in range(len(batch)):
                datapoint = batch.iloc[[index]]
                if true_labels[index] == current_labels[index]:
                    temp_dp = categorical_gaussian_perturb(datapoint, correlation_dict, sigmas, categorical_features)
                    temp_dp = numerical_gaussian_perturb(temp_dp, correlation_dict, sigmas, numerical_features)
                    batch.iloc[[index]] = temp_dp

            # Get predictions after perturbation
            current_labels,_ = predict_LM(batch) if modelArch == "LM" else predict_GBT(batch)

            # Revert datapoints that failed to flip prediction
            for index in range(len(batch)):
                if true_labels[index] == current_labels[index]:
                    batch.iloc[[index]] = true_batch.iloc[[index]]

            print(f"{perturb_iteration + 1}/{num_perturb_iterations} Accuracy: {sum(current_labels==true_labels)/len(batch)}")

        # Mark successful adversarial examples (flipped predictions)
        successfully_flipped = (current_labels != true_labels) & (original_incorrect_predictions == False)

        # -------------------------------------------------------------------------------
        #                             Minimization Loop
        # -------------------------------------------------------------------------------
        # Track saturation of features per sample
        feature_saturation_map = [set() for _ in range(len(batch))]
        datapoint_saturated = ~successfully_flipped
        minimization_distances = []

        # Initialize saturated features (those already equal to original)
        for datapoint_index in range(len(batch)):
            for feature in batch.columns:
                current_val = batch.iloc[datapoint_index][feature]
                original_val = true_batch.iloc[datapoint_index][feature]
                if current_val == original_val:
                    feature_saturation_map[datapoint_index].add(feature)

        # Run minimization steps
        for minimize_iteration in range(num_minimize_iterations):
            # Measure current perturbation distance
            distance = batch_distance_score(true_batch, batch, correlation_dict)
            minimization_distances.append(distance)

            # Backup batch before minimization
            batch_before_minimization = batch.copy()
            labels_before_minimization,_ = predict_LM(batch_before_minimization) if modelArch == "LM" else predict_GBT(batch_before_minimization)

            for datapoint_index in range(len(batch)):
                if datapoint_saturated[datapoint_index]:
                    continue  # Skip already saturated samples

                datapoint = batch.iloc[[datapoint_index]]
                original_datapoint = true_batch.iloc[[datapoint_index]]

                # Select and minimize the most changed feature
                feature = find_feature_to_minimize(datapoint, original_datapoint, correlation_dict, feature_saturation_map[datapoint_index])
                datapoint_minimized = minimize_feature(datapoint, feature, correlation_dict, true_batch.iloc[[datapoint_index]])
                batch.iloc[[datapoint_index]] = datapoint_minimized

                # Mark feature as saturated if it reached original value
                if datapoint_minimized[feature].iloc[0] == original_datapoint[feature].iloc[0]:
                    feature_saturation_map[datapoint_index].add(feature)

            # Get predictions after minimization
            current_labels,_ = predict_LM(batch) if modelArch == "LM" else predict_GBT(batch)

            for datapoint_index in range(len(batch)):
                if datapoint_saturated[datapoint_index]:
                    continue

                if current_labels[datapoint_index] == true_labels[datapoint_index]:
                    # Prediction reverted — undo minimization
                    batch.iloc[[datapoint_index]] = batch_before_minimization.iloc[[datapoint_index]]

                    # Mark the attempted feature as saturated
                    last_feature = find_feature_to_minimize(
                        batch_before_minimization.iloc[[datapoint_index]],
                        original_datapoint,
                        correlation_dict,
                        feature_saturation_map[datapoint_index]
                    )
                    feature_saturation_map[datapoint_index].add(last_feature)

                # Check if all features are now saturated
                if len(feature_saturation_map[datapoint_index]) >= len(batch.columns):
                    datapoint_saturated[datapoint_index] = True

            # Early exit if all samples are saturated
            if all(datapoint_saturated):
                print(f"All datapoints saturated. Exiting minimization loop early. Iteration num: {minimize_iteration}")
                break

        all_perturbation_accuracies.append(perturbation_accuracies)
        all_minimization_distances.append(minimization_distances)

        # Final predictions after perturbation + minimization
        final_predictions, final_scores = predict_LM(batch) if modelArch == "LM" else predict_GBT(batch)

        # Annotate adversarial success per row
        batch['original_label'] = true_labels
        batch['original_prediction'] = original_predictions
        batch['final_prediction'] = final_predictions
        batch['IsCorrect'] = batch['original_label'] == batch['original_prediction']
        batch['IsAdversarial'] = (batch['original_label'] != batch['final_prediction']) & batch['IsCorrect']

        # Add score columns
        batch['score_before_attack'] = original_scores
        batch['score_after_attack'] = final_scores

        # Store final adversarial batch
        all_adversarial_batches.append(batch)

    # Combine all batches into a single DataFrame
    full_adversarial_dataset = pd.concat(all_adversarial_batches, ignore_index=True)
    print("\nAdversarial dataset generation complete!")

    return full_adversarial_dataset, all_perturbation_accuracies, all_minimization_distances, batch_sizes

# %% [markdown]
# ##  **Implement Attack on GBT**

# %% [markdown]
# ### Attack Parameters

# %%
# Standard deviation values for Gaussian sampling per feature (used during perturbation)
sigmas = {
    'age': 3,
    'workclass': 0.05,
    'education': 0.03,
    'educational-num': 1,
    'marital-status': 0.3,
    'occupation': 0.01,
    'relationship': 0.2,
    'race': 0.05,
    'gender': 0.4,
    'capital-gain': 100,
    'capital-loss': 100,
    'hours-per-week': 2,
    'native-country': 0.03
}

# Define feature groups
numerical_features = ['age', 'educational-num', 'capital-gain', 'capital-loss', 'hours-per-week']
categorical_features = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'native-country']
all_features = numerical_features + categorical_features

# Attack parameters
batch_size = 32
num_perturb_iterations = 5
num_minimize_iterations = 50
modelArch = "GBT"                   # Model type: "GBT" or "LM"

# %% [markdown]
# ###Implement Attack

# %%
# Define subset for attack
df_to_attack = df.copy()

# Run the adversarial attack and collect results
adversarial_df_GBT, accuracies_GBT, distances_GBT, batch_sizes_GBT = generate_adversarial_dataset(
    df_to_attack,
    modelArch,
    correlation_dict,
    sigmas,
    numerical_features,
    categorical_features,
    num_perturb_iterations,
    num_minimize_iterations,
    batch_size=32,
    random_seed=42
)

# Save adversarial dataset to CSV file
os.makedirs('results', exist_ok=True)  # Create output directory if it doesn't exist
adversarial_df_GBT.to_csv('results/adversarial_df_GBT.csv', index=False)

# List output files (for Colab visualization)
# !ls results

# Download the CSV file to local machine (Colab only)
from google.colab import files
files.download('results/adversarial_df_GBT.csv')
# Out:
# --- Processing batch starting from row 0 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.71875
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 25
#
# --- Processing batch starting from row 32 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 28
#
# --- Processing batch starting from row 64 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.53125
# 2/5 Accuracy: 0.46875
# 3/5 Accuracy: 0.40625
# 4/5 Accuracy: 0.34375
# 5/5 Accuracy: 0.3125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 28
#
# --- Processing batch starting from row 96 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.46875
#
# --- Processing batch starting from row 128 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 14
#
# --- Processing batch starting from row 160 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.84375
# 2/5 Accuracy: 0.78125
# 3/5 Accuracy: 0.65625
# 4/5 Accuracy: 0.625
# 5/5 Accuracy: 0.625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 29
#
# --- Processing batch starting from row 192 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 42
#
# --- Processing batch starting from row 224 ---
# Original accuracy: 0.75
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.46875
# 3/5 Accuracy: 0.46875
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 34
#
# --- Processing batch starting from row 256 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.4375
# 4/5 Accuracy: 0.34375
# 5/5 Accuracy: 0.3125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 44
#
# --- Processing batch starting from row 288 ---
# Original accuracy: 0.65625
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.40625
# 4/5 Accuracy: 0.3125
# 5/5 Accuracy: 0.3125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 25
#
# --- Processing batch starting from row 320 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.46875
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.40625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 18
#
# --- Processing batch starting from row 352 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 22
#
# --- Processing batch starting from row 384 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.6875
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 40
#
# --- Processing batch starting from row 416 ---
# Original accuracy: 0.9375
# 1/5 Accuracy: 0.84375
# 2/5 Accuracy: 0.8125
# 3/5 Accuracy: 0.71875
# 4/5 Accuracy: 0.71875
# 5/5 Accuracy: 0.6875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 22
#
# --- Processing batch starting from row 448 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 38
#
# --- Processing batch starting from row 480 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.84375
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.65625
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.59375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 16
#
# --- Processing batch starting from row 512 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.75
# 3/5 Accuracy: 0.65625
# 4/5 Accuracy: 0.625
# 5/5 Accuracy: 0.59375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 19
#
# --- Processing batch starting from row 544 ---
# Original accuracy: 0.96875
# 1/5 Accuracy: 0.8125
# 2/5 Accuracy: 0.75
# 3/5 Accuracy: 0.6875
# 4/5 Accuracy: 0.6875
# 5/5 Accuracy: 0.65625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 23
#
# --- Processing batch starting from row 576 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.625
# 5/5 Accuracy: 0.59375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 45
#
# --- Processing batch starting from row 608 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 31
#
# --- Processing batch starting from row 640 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.8125
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.59375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 22
#
# --- Processing batch starting from row 672 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.6875
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 26
#
# --- Processing batch starting from row 704 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 14
#
# --- Processing batch starting from row 736 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.8125
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.65625
# 4/5 Accuracy: 0.625
# 5/5 Accuracy: 0.59375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 23
#
# --- Processing batch starting from row 768 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 47
#
# --- Processing batch starting from row 800 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.65625
# 4/5 Accuracy: 0.65625
# 5/5 Accuracy: 0.625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 32
#
# --- Processing batch starting from row 832 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.46875
# 4/5 Accuracy: 0.4375
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 23
#
# --- Processing batch starting from row 864 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.4375
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 34
#
# --- Processing batch starting from row 896 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 29
#
# --- Processing batch starting from row 928 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.8125
# 2/5 Accuracy: 0.78125
# 3/5 Accuracy: 0.78125
# 4/5 Accuracy: 0.75
# 5/5 Accuracy: 0.71875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 44
#
# --- Processing batch starting from row 960 ---
# Original accuracy: 0.71875
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.46875
# 3/5 Accuracy: 0.46875
# 4/5 Accuracy: 0.4375
# 5/5 Accuracy: 0.40625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 34
#
# --- Processing batch starting from row 992 ---
# Original accuracy: 0.75
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.4375
# 4/5 Accuracy: 0.40625
# 5/5 Accuracy: 0.40625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 23
#
# --- Processing batch starting from row 1024 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.65625
# 4/5 Accuracy: 0.65625
# 5/5 Accuracy: 0.65625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 22
#
# --- Processing batch starting from row 1056 ---
# Original accuracy: 0.71875
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 49
#
# --- Processing batch starting from row 1088 ---
# Original accuracy: 0.75
# 1/5 Accuracy: 0.5625
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.4375
# 4/5 Accuracy: 0.40625
# 5/5 Accuracy: 0.375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 45
#
# --- Processing batch starting from row 1120 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 16
#
# --- Processing batch starting from row 1152 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 25
#
# --- Processing batch starting from row 1184 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 20
#
# --- Processing batch starting from row 1216 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.5
# 3/5 Accuracy: 0.4375
# 4/5 Accuracy: 0.4375
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 41
#
# --- Processing batch starting from row 1248 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 34
#
# --- Processing batch starting from row 1280 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.78125
# 3/5 Accuracy: 0.75
# 4/5 Accuracy: 0.71875
# 5/5 Accuracy: 0.65625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 45
#
# --- Processing batch starting from row 1312 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.71875
# 3/5 Accuracy: 0.6875
# 4/5 Accuracy: 0.65625
# 5/5 Accuracy: 0.625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 21
#
# --- Processing batch starting from row 1344 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 31
#
# --- Processing batch starting from row 1376 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 36
#
# --- Processing batch starting from row 1408 ---
# Original accuracy: 0.71875
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 34
#
# --- Processing batch starting from row 1440 ---
# Original accuracy: 0.75
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 24
#
# --- Processing batch starting from row 1472 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 32
#
# --- Processing batch starting from row 1504 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 27
#
# --- Processing batch starting from row 1536 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 24
#
# --- Processing batch starting from row 1568 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.46875
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.40625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 34
#
# --- Processing batch starting from row 1600 ---
# Original accuracy: 0.9375
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.78125
# 3/5 Accuracy: 0.75
# 4/5 Accuracy: 0.71875
# 5/5 Accuracy: 0.71875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 14
#
# --- Processing batch starting from row 1632 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.71875
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 28
#
# --- Processing batch starting from row 1664 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 19
#
# --- Processing batch starting from row 1696 ---
# Original accuracy: 0.6875
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.46875
# 3/5 Accuracy: 0.375
# 4/5 Accuracy: 0.375
# 5/5 Accuracy: 0.34375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 28
#
# --- Processing batch starting from row 1728 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.53125
#
# --- Processing batch starting from row 1760 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.59375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 20
#
# --- Processing batch starting from row 1792 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.625
# 5/5 Accuracy: 0.625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 38
#
# --- Processing batch starting from row 1824 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 33
#
# --- Processing batch starting from row 1856 ---
# Original accuracy: 0.75
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.4375
# 4/5 Accuracy: 0.4375
# 5/5 Accuracy: 0.40625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 26
#
# --- Processing batch starting from row 1888 ---
# Original accuracy: 0.9375
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.4375
# 4/5 Accuracy: 0.375
# 5/5 Accuracy: 0.34375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 46
#
# --- Processing batch starting from row 1920 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 17
#
# --- Processing batch starting from row 1952 ---
# Original accuracy: 0.75
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.59375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 16
#
# --- Processing batch starting from row 1984 ---
# Original accuracy: 0.65625
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.5
# 3/5 Accuracy: 0.46875
# 4/5 Accuracy: 0.4375
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 18
#
# --- Processing batch starting from row 2016 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 48
#
# --- Processing batch starting from row 2048 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 41
#
# --- Processing batch starting from row 2080 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 25
#
# --- Processing batch starting from row 2112 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.71875
# 3/5 Accuracy: 0.6875
# 4/5 Accuracy: 0.625
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 34
#
# --- Processing batch starting from row 2144 ---
# Original accuracy: 0.75
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 30
#
# --- Processing batch starting from row 2176 ---
# Original accuracy: 0.75
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 26
#
# --- Processing batch starting from row 2208 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 31
#
# --- Processing batch starting from row 2240 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 32
#
# --- Processing batch starting from row 2272 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.65625
# 4/5 Accuracy: 0.625
# 5/5 Accuracy: 0.625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 28
#
# --- Processing batch starting from row 2304 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 19
#
# --- Processing batch starting from row 2336 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 21
#
# --- Processing batch starting from row 2368 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 35
#
# --- Processing batch starting from row 2400 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 37
#
# --- Processing batch starting from row 2432 ---
# Original accuracy: 0.9375
# 1/5 Accuracy: 0.875
# 2/5 Accuracy: 0.8125
# 3/5 Accuracy: 0.8125
# 4/5 Accuracy: 0.75
# 5/5 Accuracy: 0.75
# All datapoints saturated. Exiting minimization loop early. Iteration num: 22
#
# --- Processing batch starting from row 2464 ---
# Original accuracy: 0.9375
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 35
#
# --- Processing batch starting from row 2496 ---
# Original accuracy: 0.75
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.65625
# 4/5 Accuracy: 0.625
# 5/5 Accuracy: 0.625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 18
#
# --- Processing batch starting from row 2528 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.5625
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.4375
# 5/5 Accuracy: 0.375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 18
#
# --- Processing batch starting from row 2560 ---
# Original accuracy: 0.9375
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 25
#
# --- Processing batch starting from row 2592 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.40625
# 3/5 Accuracy: 0.375
# 4/5 Accuracy: 0.375
# 5/5 Accuracy: 0.3125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 46
#
# --- Processing batch starting from row 2624 ---
# Original accuracy: 0.71875
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 28
#
# --- Processing batch starting from row 2656 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.78125
# 3/5 Accuracy: 0.71875
# 4/5 Accuracy: 0.6875
# 5/5 Accuracy: 0.65625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 20
#
# --- Processing batch starting from row 2688 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.4375
# 4/5 Accuracy: 0.375
# 5/5 Accuracy: 0.34375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 30
#
# --- Processing batch starting from row 2720 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.46875
#
# --- Processing batch starting from row 2752 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.6875
# 4/5 Accuracy: 0.65625
# 5/5 Accuracy: 0.65625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 25
#
# --- Processing batch starting from row 2784 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.8125
# 2/5 Accuracy: 0.71875
# 3/5 Accuracy: 0.6875
# 4/5 Accuracy: 0.625
# 5/5 Accuracy: 0.59375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 42
#
# --- Processing batch starting from row 2816 ---
# Original accuracy: 0.9375
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.78125
# 3/5 Accuracy: 0.78125
# 4/5 Accuracy: 0.625
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 36
#
# --- Processing batch starting from row 2848 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.625
# 5/5 Accuracy: 0.59375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 30
#
# --- Processing batch starting from row 2880 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.40625
# 5/5 Accuracy: 0.40625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 31
#
# --- Processing batch starting from row 2912 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 34
#
# --- Processing batch starting from row 2944 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 23
#
# --- Processing batch starting from row 2976 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.40625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 23
#
# --- Processing batch starting from row 3008 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 17
#
# --- Processing batch starting from row 3040 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 43
#
# --- Processing batch starting from row 3072 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 39
#
# --- Processing batch starting from row 3104 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 33
#
# --- Processing batch starting from row 3136 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 32
#
# --- Processing batch starting from row 3168 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.5
# 2/5 Accuracy: 0.375
# 3/5 Accuracy: 0.375
# 4/5 Accuracy: 0.375
# 5/5 Accuracy: 0.34375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 24
#
# --- Processing batch starting from row 3200 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.5
# 3/5 Accuracy: 0.46875
# 4/5 Accuracy: 0.40625
# 5/5 Accuracy: 0.375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 22
#
# --- Processing batch starting from row 3232 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.8125
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 44
#
# --- Processing batch starting from row 3264 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 36
#
# --- Processing batch starting from row 3296 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.4375
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 24
#
# --- Processing batch starting from row 3328 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.65625
# 4/5 Accuracy: 0.65625
# 5/5 Accuracy: 0.65625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 43
#
# --- Processing batch starting from row 3360 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 19
#
# --- Processing batch starting from row 3392 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.46875
# 3/5 Accuracy: 0.4375
# 4/5 Accuracy: 0.375
# 5/5 Accuracy: 0.3125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 29
#
# --- Processing batch starting from row 3424 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 39
#
# --- Processing batch starting from row 3456 ---
# Original accuracy: 0.6875
# 1/5 Accuracy: 0.53125
# 2/5 Accuracy: 0.46875
# 3/5 Accuracy: 0.375
# 4/5 Accuracy: 0.375
# 5/5 Accuracy: 0.375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 34
#
# --- Processing batch starting from row 3488 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 45
#
# --- Processing batch starting from row 3520 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 30
#
# --- Processing batch starting from row 3552 ---
# Original accuracy: 0.6875
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.5
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 25
#
# --- Processing batch starting from row 3584 ---
# Original accuracy: 0.75
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 23
#
# --- Processing batch starting from row 3616 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.8125
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.625
# 5/5 Accuracy: 0.625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 35
#
# --- Processing batch starting from row 3648 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.8125
# 2/5 Accuracy: 0.71875
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.625
# 5/5 Accuracy: 0.625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 40
#
# --- Processing batch starting from row 3680 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 36
#
# --- Processing batch starting from row 3712 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 28
#
# --- Processing batch starting from row 3744 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 27
#
# --- Processing batch starting from row 3776 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.4375
# 5/5 Accuracy: 0.40625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 47
#
# --- Processing batch starting from row 3808 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.71875
# 3/5 Accuracy: 0.6875
# 4/5 Accuracy: 0.625
# 5/5 Accuracy: 0.625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 22
#
# --- Processing batch starting from row 3840 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.40625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 27
#
# --- Processing batch starting from row 3872 ---
# Original accuracy: 0.75
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.5
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 26
#
# --- Processing batch starting from row 3904 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.46875
# 4/5 Accuracy: 0.40625
# 5/5 Accuracy: 0.34375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 33
#
# --- Processing batch starting from row 3936 ---
# Original accuracy: 0.75
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.65625
# 4/5 Accuracy: 0.625
# 5/5 Accuracy: 0.59375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 26
#
# --- Processing batch starting from row 3968 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.5
# 3/5 Accuracy: 0.4375
# 4/5 Accuracy: 0.4375
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 25
#
# --- Processing batch starting from row 4000 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 26
#
# --- Processing batch starting from row 4032 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.5
# 3/5 Accuracy: 0.4375
# 4/5 Accuracy: 0.40625
# 5/5 Accuracy: 0.40625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 27
#
# --- Processing batch starting from row 4064 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 24
#
# --- Processing batch starting from row 4096 ---
# Original accuracy: 0.625
# 1/5 Accuracy: 0.5625
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.4375
# 4/5 Accuracy: 0.40625
# 5/5 Accuracy: 0.375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 48
#
# --- Processing batch starting from row 4128 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.5625
#
# --- Processing batch starting from row 4160 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 47
#
# --- Processing batch starting from row 4192 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 37
#
# --- Processing batch starting from row 4224 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.8125
# 2/5 Accuracy: 0.71875
# 3/5 Accuracy: 0.6875
# 4/5 Accuracy: 0.6875
# 5/5 Accuracy: 0.6875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 28
#
# --- Processing batch starting from row 4256 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.5
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 23
#
# --- Processing batch starting from row 4288 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.90625
# 2/5 Accuracy: 0.875
# 3/5 Accuracy: 0.8125
# 4/5 Accuracy: 0.78125
# 5/5 Accuracy: 0.75
# All datapoints saturated. Exiting minimization loop early. Iteration num: 38
#
# --- Processing batch starting from row 4320 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 30
#
# --- Processing batch starting from row 4352 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.84375
# 2/5 Accuracy: 0.8125
# 3/5 Accuracy: 0.75
# 4/5 Accuracy: 0.75
# 5/5 Accuracy: 0.71875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 12
#
# --- Processing batch starting from row 4384 ---
# Original accuracy: 0.6875
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.4375
# 4/5 Accuracy: 0.40625
# 5/5 Accuracy: 0.34375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 37
#
# --- Processing batch starting from row 4416 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.71875
# 3/5 Accuracy: 0.65625
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.59375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 24
#
# --- Processing batch starting from row 4448 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.625
# 5/5 Accuracy: 0.59375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 35
#
# --- Processing batch starting from row 4480 ---
# Original accuracy: 0.75
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.4375
# 4/5 Accuracy: 0.34375
# 5/5 Accuracy: 0.34375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 31
#
# --- Processing batch starting from row 4512 ---
# Original accuracy: 0.71875
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.40625
# 4/5 Accuracy: 0.40625
# 5/5 Accuracy: 0.34375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 26
#
# --- Processing batch starting from row 4544 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.65625
# 4/5 Accuracy: 0.625
# 5/5 Accuracy: 0.59375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 43
#
# --- Processing batch starting from row 4576 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.59375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 27
#
# --- Processing batch starting from row 4608 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.53125
# 2/5 Accuracy: 0.4375
# 3/5 Accuracy: 0.4375
# 4/5 Accuracy: 0.40625
# 5/5 Accuracy: 0.375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 24
#
# --- Processing batch starting from row 4640 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.53125
#
# --- Processing batch starting from row 4672 ---
# Original accuracy: 0.9375
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.625
# 5/5 Accuracy: 0.625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 37
#
# --- Processing batch starting from row 4704 ---
# Original accuracy: 0.6875
# 1/5 Accuracy: 0.53125
# 2/5 Accuracy: 0.375
# 3/5 Accuracy: 0.34375
# 4/5 Accuracy: 0.34375
# 5/5 Accuracy: 0.34375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 36
#
# --- Processing batch starting from row 4736 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.5625
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 36
#
# --- Processing batch starting from row 4768 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.46875
#
# --- Processing batch starting from row 4800 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 26
#
# --- Processing batch starting from row 4832 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.71875
# 3/5 Accuracy: 0.6875
# 4/5 Accuracy: 0.6875
# 5/5 Accuracy: 0.65625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 22
#
# --- Processing batch starting from row 4864 ---
# Original accuracy: 0.96875
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.65625
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.59375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 47
#
# --- Processing batch starting from row 4896 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.59375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 29
#
# --- Processing batch starting from row 4928 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 39
#
# --- Processing batch starting from row 4960 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.59375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 18
#
# --- Processing batch starting from row 4992 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.8125
# 2/5 Accuracy: 0.71875
# 3/5 Accuracy: 0.65625
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 37
#
# --- Processing batch starting from row 5024 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 24
#
# --- Processing batch starting from row 5056 ---
# Original accuracy: 0.75
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 23
#
# --- Processing batch starting from row 5088 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 40
#
# --- Processing batch starting from row 5120 ---
# Original accuracy: 0.75
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 26
#
# --- Processing batch starting from row 5152 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 40
#
# --- Processing batch starting from row 5184 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.5
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 40
#
# --- Processing batch starting from row 5216 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 47
#
# --- Processing batch starting from row 5248 ---
# Original accuracy: 0.75
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.40625
# 5/5 Accuracy: 0.375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 18
#
# --- Processing batch starting from row 5280 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 31
#
# --- Processing batch starting from row 5312 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.40625
# 5/5 Accuracy: 0.40625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 32
#
# --- Processing batch starting from row 5344 ---
# Original accuracy: 0.6875
# 1/5 Accuracy: 0.5625
# 2/5 Accuracy: 0.46875
# 3/5 Accuracy: 0.46875
# 4/5 Accuracy: 0.40625
# 5/5 Accuracy: 0.34375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 46
#
# --- Processing batch starting from row 5376 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 30
#
# --- Processing batch starting from row 5408 ---
# Original accuracy: 0.6875
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 35
#
# --- Processing batch starting from row 5440 ---
# Original accuracy: 0.9375
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 43
#
# --- Processing batch starting from row 5472 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 37
#
# --- Processing batch starting from row 5504 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.59375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 19
#
# --- Processing batch starting from row 5536 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.75
# 3/5 Accuracy: 0.71875
# 4/5 Accuracy: 0.65625
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 21
#
# --- Processing batch starting from row 5568 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 33
#
# --- Processing batch starting from row 5600 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 49
#
# --- Processing batch starting from row 5632 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.46875
# 4/5 Accuracy: 0.4375
# 5/5 Accuracy: 0.375
#
# --- Processing batch starting from row 5664 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.71875
# 3/5 Accuracy: 0.6875
# 4/5 Accuracy: 0.65625
# 5/5 Accuracy: 0.65625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 23
#
# --- Processing batch starting from row 5696 ---
# Original accuracy: 0.9375
# 1/5 Accuracy: 0.84375
# 2/5 Accuracy: 0.78125
# 3/5 Accuracy: 0.6875
# 4/5 Accuracy: 0.65625
# 5/5 Accuracy: 0.625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 18
#
# --- Processing batch starting from row 5728 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 43
#
# --- Processing batch starting from row 5760 ---
# Original accuracy: 0.6875
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 39
#
# --- Processing batch starting from row 5792 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.5
# 3/5 Accuracy: 0.46875
# 4/5 Accuracy: 0.4375
# 5/5 Accuracy: 0.40625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 32
#
# --- Processing batch starting from row 5824 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 24
#
# --- Processing batch starting from row 5856 ---
# Original accuracy: 0.71875
# 1/5 Accuracy: 0.5625
# 2/5 Accuracy: 0.5
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 31
#
# --- Processing batch starting from row 5888 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.4375
# 5/5 Accuracy: 0.34375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 36
#
# --- Processing batch starting from row 5920 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.75
# 3/5 Accuracy: 0.6875
# 4/5 Accuracy: 0.6875
# 5/5 Accuracy: 0.6875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 25
#
# --- Processing batch starting from row 5952 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.46875
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 37
#
# --- Processing batch starting from row 5984 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.71875
# 3/5 Accuracy: 0.6875
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 28
#
# --- Processing batch starting from row 6016 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.53125
# ...
# --- Processing batch starting from row 6976 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 21
#
# --- Processing batch starting from row 7008 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.5
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.40625
# 5/5 Accuracy: 0.40625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 42
#
# --- Processing batch starting from row 7040 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 30
#
# --- Processing batch starting from row 7072 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.40625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 32
#
# --- Processing batch starting from row 7104 ---
# Original accuracy: 0.625
# 1/5 Accuracy: 0.5
# 2/5 Accuracy: 0.46875
# 3/5 Accuracy: 0.4375
# 4/5 Accuracy: 0.40625
# 5/5 Accuracy: 0.375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 21
#
# --- Processing batch starting from row 7136 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 21
#
# --- Processing batch starting from row 7168 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 24
#
# --- Processing batch starting from row 7200 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.71875
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.59375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 36
#
# --- Processing batch starting from row 7232 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 19
#
# --- Processing batch starting from row 7264 ---
# Original accuracy: 0.9375
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.625
# 5/5 Accuracy: 0.59375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 32
#
# --- Processing batch starting from row 7296 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 32
#
# --- Processing batch starting from row 7328 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 40
#
# --- Processing batch starting from row 7360 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 32
#
# --- Processing batch starting from row 7392 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.4375
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 39
#
# --- Processing batch starting from row 7424 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 29
#
# --- Processing batch starting from row 7456 ---
# Original accuracy: 0.75
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.4375
#
# --- Processing batch starting from row 7488 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.4375
# 5/5 Accuracy: 0.40625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 16
#
# --- Processing batch starting from row 7520 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 32
#
# --- Processing batch starting from row 7552 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 43
#
# --- Processing batch starting from row 7584 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.40625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 31
#
# --- Processing batch starting from row 7616 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 22
#
# --- Processing batch starting from row 7648 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 27
#
# --- Processing batch starting from row 7680 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 33
#
# --- Processing batch starting from row 7712 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.65625
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 35
#
# --- Processing batch starting from row 7744 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.46875
# 4/5 Accuracy: 0.4375
# 5/5 Accuracy: 0.375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 35
#
# --- Processing batch starting from row 7776 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.5625
# 2/5 Accuracy: 0.5
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.34375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 43
#
# --- Processing batch starting from row 7808 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 27
#
# --- Processing batch starting from row 7840 ---
# Original accuracy: 0.96875
# 1/5 Accuracy: 0.84375
# 2/5 Accuracy: 0.8125
# 3/5 Accuracy: 0.71875
# 4/5 Accuracy: 0.71875
# 5/5 Accuracy: 0.71875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 24
#
# --- Processing batch starting from row 7872 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 26
#
# --- Processing batch starting from row 7904 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.59375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 44
#
# --- Processing batch starting from row 7936 ---
# Original accuracy: 0.9375
# 1/5 Accuracy: 0.8125
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 29
#
# --- Processing batch starting from row 7968 ---
# Original accuracy: 0.71875
# 1/5 Accuracy: 0.5625
# 2/5 Accuracy: 0.40625
# 3/5 Accuracy: 0.375
# 4/5 Accuracy: 0.3125
# 5/5 Accuracy: 0.3125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 33
#
# --- Processing batch starting from row 8000 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.625
# 5/5 Accuracy: 0.59375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 45
#
# --- Processing batch starting from row 8032 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 23
#
# --- Processing batch starting from row 8064 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 23
#
# --- Processing batch starting from row 8096 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 43
#
# --- Processing batch starting from row 8128 ---
# Original accuracy: 0.6875
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.46875
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.40625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 17
#
# --- Processing batch starting from row 8160 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.5
# 3/5 Accuracy: 0.46875
# 4/5 Accuracy: 0.375
# 5/5 Accuracy: 0.375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 31
#
# --- Processing batch starting from row 8192 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 44
#
# --- Processing batch starting from row 8224 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 32
#
# --- Processing batch starting from row 8256 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.59375
# 2/5 Accuracy: 0.5
# 3/5 Accuracy: 0.46875
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 31
#
# --- Processing batch starting from row 8288 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 27
#
# --- Processing batch starting from row 8320 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 30
#
# --- Processing batch starting from row 8352 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.53125
#
# --- Processing batch starting from row 8384 ---
# Original accuracy: 0.71875
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 26
#
# --- Processing batch starting from row 8416 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.71875
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 42
#
# --- Processing batch starting from row 8448 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.65625
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 15
#
# --- Processing batch starting from row 8480 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.65625
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 28
#
# --- Processing batch starting from row 8512 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.625
# 5/5 Accuracy: 0.625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 48
#
# --- Processing batch starting from row 8544 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 35
#
# --- Processing batch starting from row 8576 ---
# Original accuracy: 0.9375
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.46875
# 5/5 Accuracy: 0.4375
#
# --- Processing batch starting from row 8608 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.5625
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 45
#
# --- Processing batch starting from row 8640 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.5
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 43
#
# --- Processing batch starting from row 8672 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.53125
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 24
#
# --- Processing batch starting from row 8704 ---
# Original accuracy: 0.78125
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 23
#
# --- Processing batch starting from row 8736 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.53125
# 5/5 Accuracy: 0.46875
# All datapoints saturated. Exiting minimization loop early. Iteration num: 26
#
# --- Processing batch starting from row 8768 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.625
# 2/5 Accuracy: 0.5
# 3/5 Accuracy: 0.46875
# 4/5 Accuracy: 0.4375
# 5/5 Accuracy: 0.4375
# All datapoints saturated. Exiting minimization loop early. Iteration num: 32
#
# --- Processing batch starting from row 8800 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.65625
# 4/5 Accuracy: 0.59375
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 26
#
# --- Processing batch starting from row 8832 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.65625
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 41
#
# --- Processing batch starting from row 8864 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.625
# 4/5 Accuracy: 0.625
# 5/5 Accuracy: 0.625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 11
#
# --- Processing batch starting from row 8896 ---
# Original accuracy: 0.8125
# 1/5 Accuracy: 0.6875
# 2/5 Accuracy: 0.6875
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.53125
# All datapoints saturated. Exiting minimization loop early. Iteration num: 14
#
# --- Processing batch starting from row 8928 ---
# Original accuracy: 0.84375
# 1/5 Accuracy: 0.71875
# 2/5 Accuracy: 0.59375
# 3/5 Accuracy: 0.5625
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 22
#
# --- Processing batch starting from row 8960 ---
# Original accuracy: 0.875
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.625
# 3/5 Accuracy: 0.5
# 4/5 Accuracy: 0.5
# 5/5 Accuracy: 0.5
# All datapoints saturated. Exiting minimization loop early. Iteration num: 17
#
# Adversarial dataset generation complete!
# adversarial_df_GBT.csv

# %% [markdown]
# ##  **Implement Attack on RoBERTa**

# %% [markdown]
# ### Attack Parameters

# %%
# Standard deviation values for Gaussian sampling per feature (used during perturbation)
sigmas = {
    'age': 3,
    'workclass': 0.05,
    'education': 0.03,
    'educational-num': 1,
    'marital-status': 0.3,
    'occupation': 0.01,
    'relationship': 0.2,
    'race': 0.05,
    'gender': 0.4,
    'capital-gain': 100,
    'capital-loss': 100,
    'hours-per-week': 2,
    'native-country': 0.03
}

# Define feature groups
numerical_features = ['age', 'educational-num', 'capital-gain', 'capital-loss', 'hours-per-week']
categorical_features = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'native-country']
all_features = numerical_features + categorical_features

# Attack parameters
batch_size = 32
num_perturb_iterations = 5
num_minimize_iterations = 50
modelArch = "LM"                   # Model type: "GBT" or "LM"

# %% [markdown]
# ###Implement Attack

# %%
# Define subset for attack
df_to_attack = df.copy()

# Run the adversarial attack and collect results
adversarial_df_LLM, accuracies_LLM, distances_LLM, batch_sizes_LLM = generate_adversarial_dataset(
    df,
    modelArch,
    correlation_dict,
    sigmas,
    numerical_features,
    categorical_features,
    num_perturb_iterations,
    num_minimize_iterations,
    batch_size=32,
    random_seed=42
)

# Save adversarial dataset to CSV file
os.makedirs('results', exist_ok=True)  # Create output directory if it doesn't exist
adversarial_df_LLM.to_csv('results/adversarial_df_LLM.csv', index=False)

# List output files (for Colab visualization)
# !ls results

# Download the CSV file to local machine (Colab only)
from google.colab import files
files.download('results/adversarial_df_LLM.csv')
# Out:
# --- Processing batch starting from row 0 ---
# Original accuracy: 0.90625
# 1/5 Accuracy: 0.78125
# 2/5 Accuracy: 0.71875
# 3/5 Accuracy: 0.6875
# 4/5 Accuracy: 0.65625
# 5/5 Accuracy: 0.625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 16
#
# --- Processing batch starting from row 32 ---
# Original accuracy: 0.9375
# 1/5 Accuracy: 0.75
# 2/5 Accuracy: 0.65625
# 3/5 Accuracy: 0.59375
# 4/5 Accuracy: 0.5625
# 5/5 Accuracy: 0.5625
# All datapoints saturated. Exiting minimization loop early. Iteration num: 10
#
# --- Processing batch starting from row 64 ---
# Original accuracy: 0.71875
# 1/5 Accuracy: 0.5625
# 2/5 Accuracy: 0.53125
# 3/5 Accuracy: 0.46875
# 4/5 Accuracy: 0.4375
# 5/5 Accuracy: 0.34375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-135-588f372f6811> in <cell line: 0>()
#       3
#       4 # Run the adversarial attack and collect results
# ----> 5 adversarial_df, accuracies, distances, batch_sizes = generate_adversarial_dataset(
#       6     df,
#       7     modelArch,
#
# <ipython-input-120-0a4ca684de5e> in generate_adversarial_dataset(df, modelArch, correlation_dict, sigmas, numerical_features, categorical_features, num_perturb_iterations, num_minimize_iterations, batch_size, random_seed)
#      98             # Backup batch before minimization
#      99             batch_before_minimization = batch.copy()
# --> 100             labels_before_minimization,_ = predict_LM(batch_before_minimization) if modelArch == "LM" else predict_GBT(batch_before_minimization)
#     101
#     102             for datapoint_index in range(len(batch)):
#
# <ipython-input-119-a87f4c64502f> in predict_LM(df)
#      49
#      50     # Locate the positions of mask tokens in the input
# ---> 51     mask_batch_indices, mask_token_indices = (encoded['input_ids'] == mask_token_id).nonzero(as_tuple=True)
#      52
#      53     # Initialize result arrays
#
# KeyboardInterrupt:

# %% [markdown]
# # **4. Evaluation**

# %% [markdown]
# ## 4.1 Helper Functions

# %% [markdown]
# ### Correlation Distance Summary
# This function summarizes final correlation distances per batch and computes the overall weighted average across all adversarial samples.

# %%
def print_weighted_correlation_summary(distances, batch_sizes):

    print(f"Total number of batches: {len(distances)}")
    print("\nFinal correlation distance from original samples:")

    weighted_sum = 0
    total_size = 0

    for i, batch_distances in enumerate(distances):
        if batch_distances and i < len(batch_sizes):
            final_distance = float(batch_distances[-1])
            batch_size = batch_sizes[i]
            weighted_sum += final_distance * batch_size
            total_size += batch_size
            print(f"Batch {i + 1} - {final_distance:.6f}")
        else:
            print(f"Batch {i + 1} - No data")

    if total_size > 0:
        weighted_avg = weighted_sum / total_size
        print(f"\nOverall weighted average distance across all adversarial samples: {weighted_avg:.6f}")
    else:
        print("\nNo valid distances to summarize.")

# %% [markdown]
# ### Adversarial Feature Change Summary
# Analyzes which features were changed in adversarial samples, computes success rate, and shows how often each feature was modified.

# %%
def summarize_feature_changes(original_df, adversarial_df, features):
    # Align rows
    original_df = original_df.reset_index(drop=True)
    adversarial_df = adversarial_df.reset_index(drop=True)

    # Count changes per feature
    change_counts = {}
    for feature in features:
        changes = original_df[feature] != adversarial_df[feature]
        change_counts[feature] = int(changes.sum())

    # Compute summary stats
    total_samples = len(adversarial_df)
    attempted_attacks = (adversarial_df['IsCorrect'] == True).sum()
    successful_attacks = adversarial_df['IsAdversarial'].sum()
    total_feature_changes = sum(change_counts.values())
    success_rate = (successful_attacks / attempted_attacks) * 100 if attempted_attacks else 0

    # Print global summary
    print("=== Adversarial Change Summary ===\n")
    print(f"Total datapoints: {total_samples}")
    print(f"Attempted attacks (on correct predictions): {attempted_attacks}")
    print(f"Successful attacks (prediction flipped):    {successful_attacks}")
    print(f"Success rate: {success_rate:.2f}%")
    print(f"Total number of feature-level changes:      {total_feature_changes}\n")

    # Print feature-level summary
    print("=== Feature-Level Change Stats ===\n")
    for feature in features:
        count = change_counts[feature]
        # How many of the successful attacks involved a change in this feature
        successful_change_rate = count / successful_attacks if successful_attacks else 0
        fraction_of_total_change = count / total_feature_changes if total_feature_changes else 0

        print(f"{feature}:")
        print(f"  - Changed in {count} rows ({successful_change_rate:.2%} of successful attacks)")
        print(f"  - Fraction of total changes: {fraction_of_total_change:.2%}\n")

# %% [markdown]
# ### Display Example Adversarial Attacks
# Prints a detailed comparison between original and adversarial samples for the first n successful attacks. Shows which features changed and computes a correlation-based distance score.

# %%
def display_attacks(original_df, adversarial_df, correlation_dict, all_features, n=5):
    count = 0

    for i in range(len(original_df)):
        adversarial_dp = adversarial_df.iloc[i]

        # Only show successful attacks
        if not adversarial_dp.get("IsAdversarial", False):
            continue

        original_dp = original_df.iloc[i]

        print(f"\n=== Attack #{count + 1} ===")
        print("Original:")
        print(original_dp[all_features])

        print("\nAdversarial:")
        print(adversarial_dp[all_features + ['original_label', 'original_prediction', 'final_prediction']])

        # Features that changed
        changed_features = [
            feature for feature in all_features
            if original_dp[feature] != adversarial_dp.get(feature, None)
        ]
        print("\nChanged features:")
        print(changed_features if changed_features else "None")

        # Compute L2 distance using correlation_dict
        squared_diffs = []
        for feature in all_features:
            orig_val = original_dp[feature]
            adv_val = adversarial_dp.get(feature, None)
            orig_corr = correlation_dict[feature].get(orig_val, 0.0)
            adv_corr = correlation_dict[feature].get(adv_val, 0.0)
            squared_diffs.append((orig_corr - adv_corr) ** 2)

        distance_score = np.sqrt(np.sum(squared_diffs))
        print(f"\nDistance score: {distance_score:.6f}")

        count += 1
        if count >= n:
            break

# %% [markdown]
# ### Compare Model Performance Before and After Attack
# Evaluates and prints accuracy, precision, recall, and F1-score for the model before and after adversarial attacks. Helps quantify performance degradation caused by the attack.

# %%
def compare_attack_results(original_df, adversarial_df, y_column='income'):

    # Prepare original labels (y = 1 if >50K, else 0)
    y_original = original_df[y_column].apply(lambda x: 1 if str(x).strip() == '>50K' else 0)

    # Predictions (already stored in adversarial_df)
    y_pred_original = adversarial_df['original_prediction']
    y_pred_attacked = adversarial_df['final_prediction']
    y_attacked = adversarial_df['original_label']  # true labels for the attacked set

    # Compute metrics
    original_accuracy = accuracy_score(y_original, y_pred_original)
    original_precision = precision_score(y_original, y_pred_original)
    original_recall = recall_score(y_original, y_pred_original)
    original_f1 = f1_score(y_original, y_pred_original)

    attacked_accuracy = accuracy_score(y_attacked, y_pred_attacked)
    attacked_precision = precision_score(y_attacked, y_pred_attacked)
    attacked_recall = recall_score(y_attacked, y_pred_attacked)
    attacked_f1 = f1_score(y_attacked, y_pred_attacked)

    # Print comparison
    print("\n=== Model Performance Comparison ===")
    print(f"Original Accuracy:  {original_accuracy:.4f} | Attacked Accuracy:  {attacked_accuracy:.4f}")
    print(f"Original Precision: {original_precision:.4f} | Attacked Precision: {attacked_precision:.4f}")
    print(f"Original Recall:    {original_recall:.4f} | Attacked Recall:    {attacked_recall:.4f}")
    print(f"Original F1-Score:  {original_f1:.4f} | Attacked F1-Score:  {attacked_f1:.4f}")

    # Accuracy drop
    acc_drop = original_accuracy - attacked_accuracy
    print(f"\n Accuracy Drop due to Attack: {acc_drop:.4f} ({acc_drop * 100:.2f}% decrease)")

# %% [markdown]
# ###  Plot ROC Curve Before and After Attack
# Plots and compares the ROC curves and AUC scores for the original and adversarial datasets. Useful for visualizing how attack strategies impact model discrimination ability.

# %%
def plot_roc_comparison(df_attacked, label_col='original_label', original_score_col='original_score', attacked_score_col='attacked_score'):
    # Extract true labels
    y_true = df_attacked[label_col]

    # Extract scores
    y_score_orig = df_attacked[original_score_col]
    y_score_att = df_attacked[attacked_score_col]

    # Compute ROC and AUC
    fpr_orig, tpr_orig, _ = roc_curve(y_true, y_score_orig)
    auc_orig = roc_auc_score(y_true, y_score_orig)

    fpr_att, tpr_att, _ = roc_curve(y_true, y_score_att)
    auc_att = roc_auc_score(y_true, y_score_att)

    # Plot
    plt.figure(figsize=(8, 6))
    plt.plot(fpr_orig, tpr_orig, label=f"Original (AUC = {auc_orig:.4f})", linewidth=2)
    plt.plot(fpr_att, tpr_att, label=f"Attacked (AUC = {auc_att:.4f})", linestyle='--', linewidth=2)
    plt.plot([0, 1], [0, 1], 'k--', label="Random Classifier (AUC = 0.5)")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve: Original vs Attacked")
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.show()

# %% [markdown]
# ### PCA Projection Before vs After Attack
#
# Shows side-by-side PCA plots of the original and attacked datasets, based on selected features. Points are colored by true vs. predicted labels.

# %%
def plot_pca_projection(
    df_original,
    df_attacked,
    encoders,
    title_prefix='',

):
    class_map={0: '<= 50k', 1: '> 50k'}
    custom_colors={'<= 50k': 'lightsteelblue', '> 50k': 'dimgrey'}

    # Define feature groups
    numerical_features = ['age', 'educational-num', 'capital-gain', 'capital-loss', 'hours-per-week']
    categorical_features = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'native-country']
    all_features = numerical_features + categorical_features

    def encode_df(df, label_column):
        df = df.copy()

        # Apply label encoders to categorical features
        for col in categorical_features:
            if col in encoders:
                df[col] = encoders[col].transform(df[col])
            else:
                raise ValueError(f"No encoder found for column: {col}")

        features = df[all_features]
        labels_raw = df[label_column].values
        labels = np.vectorize(class_map.get)(labels_raw)
        return features.values, labels

    # Encode both datasets
    X_orig, y_orig = encode_df(df_original, label_column='income_binary')
    X_attacked, y_attacked = encode_df(df_attacked, label_column='final_prediction')

    # Normalize
    scaler = StandardScaler()
    X_orig_scaled = scaler.fit_transform(X_orig)
    X_att_scaled = scaler.transform(X_attacked)

    # PCA
    pca = PCA(n_components=2)
    X_orig_pca = pca.fit_transform(X_orig_scaled)
    X_att_pca = pca.transform(X_att_scaled)

    # Plotting
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))

    for label in np.unique(y_orig):
        idx = y_orig == label
        axes[0].scatter(X_orig_pca[idx, 0], X_orig_pca[idx, 1],
                        c=custom_colors[label], label=label, alpha=0.6)
    axes[0].set_title(f'{title_prefix}Original Data')
    axes[0].set_xlabel('PC1')
    axes[0].set_ylabel('PC2')
    axes[0].legend(title='Income')

    for label in np.unique(y_attacked):
        idx = y_attacked == label
        axes[1].scatter(X_att_pca[idx, 0], X_att_pca[idx, 1],
                        c=custom_colors[label], label=label, alpha=0.6)
    axes[1].set_title(f'{title_prefix}Attacked Data')
    axes[1].set_xlabel('PC1')
    axes[1].set_ylabel('PC2')
    axes[1].legend(title='Income')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### PCA Visualization of Adversarial Shifts
# This function plots PCA projections of the original test data and highlights a sample of adversarial changes using arrows. Red arrows represent samples that flipped from <=50K to >50K, and green arrows indicate the opposite. This visualization helps illustrate how successful attacks move data points in feature space.

# %%
def plot_adversarial_shift_arrows(
    df_original,
    df_attacked,
    encoders,
    title_prefix=''
):

    # Internal defaults
    label_column_original = 'income_binary'
    label_column_attacked = 'final_prediction'
    class_map = {0: '<= 50K', 1: '> 50K'}
    transition_colors = {(0, 1): '#FF6F61', (1, 0): '#6BA292'}
    background_colors = {0: 'lightsteelblue', 1: 'dimgrey'}
    sample_per_direction = 5
    numerical_features = ['age', 'educational-num', 'capital-gain', 'capital-loss', 'hours-per-week']
    categorical_features = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'native-country']
    all_features = numerical_features + categorical_features

    def encode_df(df, label_col):
        df = df.copy()
        for col in categorical_features:
            if col in encoders:
                df[col] = encoders[col].transform(df[col])
            else:
                raise ValueError(f"No encoder found for column '{col}'")
        features = df[all_features].values
        labels = df[label_col].astype(int).values
        return features, labels

    # Encode and scale
    X_orig, y_orig = encode_df(df_original, label_column_original)
    X_att, y_att = encode_df(df_attacked, label_column_attacked)
    scaler = StandardScaler()
    X_orig_scaled = scaler.fit_transform(X_orig)
    X_att_scaled = scaler.transform(X_att)

    # Detect changed predictions
    changed_idx = np.where(y_orig != y_att)[0]
    if len(changed_idx) == 0:
        print("No adversarial changes detected.")
        return

    X_orig_changed = X_orig_scaled[changed_idx]
    X_att_changed = X_att_scaled[changed_idx]
    y_from = y_orig[changed_idx]
    y_to = y_att[changed_idx]

    # Sample 5 from each transition type
    transition_01 = np.where((y_from == 0) & (y_to == 1))[0]
    transition_10 = np.where((y_from == 1) & (y_to == 0))[0]
    selected_01 = sample(list(transition_01), min(sample_per_direction, len(transition_01)))
    selected_10 = sample(list(transition_10), min(sample_per_direction, len(transition_10)))
    selected_idx = selected_01 + selected_10

    if not selected_idx:
        print("No valid transitions found to plot.")
        return

    X_orig_sel = X_orig_changed[selected_idx]
    X_att_sel = X_att_changed[selected_idx]
    y_from_sel = y_from[selected_idx]
    y_to_sel = y_to[selected_idx]

    # PCA projection
    pca = PCA(n_components=2)
    X_orig_pca = pca.fit_transform(X_orig_scaled)
    X_orig_sel_pca = pca.transform(X_orig_sel)
    X_att_sel_pca = pca.transform(X_att_sel)

    # Plotting
    fig, ax = plt.subplots(figsize=(10, 7))

    for label in np.unique(y_orig):
        idx = y_orig == label
        ax.scatter(X_orig_pca[idx, 0], X_orig_pca[idx, 1],
                   c=background_colors[label],
                   label=f"{class_map[label]} ",
                   alpha=0.4, s=30)

    for i in range(len(selected_idx)):
        x0, y0 = X_orig_sel_pca[i]
        x1, y1 = X_att_sel_pca[i]
        transition = (y_from_sel[i], y_to_sel[i])
        color = transition_colors.get(transition, 'gray')

        arrow = FancyArrowPatch((x0, y0), (x1, y1),
                                arrowstyle='->',
                                color=color,
                                linewidth=1.5,
                                mutation_scale=14,
                                alpha=0.85,
                                path_effects=[
                                    pe.Stroke(linewidth=1.5, foreground='black'),
                                    pe.Normal()
                                ])
        ax.add_patch(arrow)
        ax.scatter(x1, y1, c=color, s=80, edgecolor='black', marker='o')

    ax.set_title(f'{title_prefix}PCA with Sample of Adversarial Shifts', fontsize=14)
    ax.set_xlabel('PC1')
    ax.set_ylabel('PC2')
    legend_elements = [
    Line2D([0], [0], marker='o', color='w', label='<= 50K ', markerfacecolor='lightsteelblue', markersize=8, alpha=0.8),
    Line2D([0], [0], marker='o', color='w', label='> 50K ', markerfacecolor='dimgrey', markersize=8, alpha=0.8),
    Line2D([0], [0], color='#FF6F61', lw=2, label='<=50K → >50K'),
    Line2D([0], [0], color='#6BA292', lw=2, label='>50K → <=50K')
    ]

    ax.legend(handles=legend_elements, title='Legend', loc='upper right')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 4.2 GBT Evaluation

# %%
print_weighted_correlation_summary(distances_GBT, batch_sizes_GBT)
# Out:
# Total number of batches: 281
#
# Final correlation distance from original samples:
# Batch 1 - 0.082751
# Batch 2 - 0.039938
# Batch 3 - 0.077724
# Batch 4 - 0.137459
# Batch 5 - 0.048455
# Batch 6 - 0.038074
# Batch 7 - 0.113260
# Batch 8 - 0.117625
# Batch 9 - 0.106903
# Batch 10 - 0.115401
# Batch 11 - 0.113223
# Batch 12 - 0.112047
# Batch 13 - 0.136819
# Batch 14 - 0.103039
# Batch 15 - 0.081099
# Batch 16 - 0.079854
# Batch 17 - 0.107285
# Batch 18 - 0.063440
# Batch 19 - 0.063174
# Batch 20 - 0.068618
# Batch 21 - 0.046093
# Batch 22 - 0.081910
# Batch 23 - 0.103991
# Batch 24 - 0.050636
# Batch 25 - 0.091216
# Batch 26 - 0.041939
# Batch 27 - 0.131072
# Batch 28 - 0.111973
# Batch 29 - 0.101700
# Batch 30 - 0.045365
# Batch 31 - 0.073386
# Batch 32 - 0.110991
# Batch 33 - 0.028684
# Batch 34 - 0.072382
# Batch 35 - 0.083129
# Batch 36 - 0.069196
# Batch 37 - 0.104157
# Batch 38 - 0.061269
# Batch 39 - 0.141114
# Batch 40 - 0.090044
# Batch 41 - 0.065903
# Batch 42 - 0.050886
# Batch 43 - 0.161330
# Batch 44 - 0.113151
# Batch 45 - 0.094948
# Batch 46 - 0.085634
# Batch 47 - 0.136175
# Batch 48 - 0.126764
# Batch 49 - 0.086625
# Batch 50 - 0.097598
# Batch 51 - 0.085194
# Batch 52 - 0.180264
# Batch 53 - 0.072147
# Batch 54 - 0.108048
# Batch 55 - 0.066587
# Batch 56 - 0.103161
# Batch 57 - 0.044794
# Batch 58 - 0.116976
# Batch 59 - 0.067054
# Batch 60 - 0.162701
# Batch 61 - 0.073593
# Batch 62 - 0.036006
# Batch 63 - 0.072406
# Batch 64 - 0.124043
# Batch 65 - 0.118518
# Batch 66 - 0.135522
# Batch 67 - 0.130659
# Batch 68 - 0.024777
# Batch 69 - 0.140167
# Batch 70 - 0.111781
# Batch 71 - 0.134627
# Batch 72 - 0.059991
# Batch 73 - 0.120393
# Batch 74 - 0.065438
# Batch 75 - 0.032393
# Batch 76 - 0.105834
# Batch 77 - 0.062566
# Batch 78 - 0.102218
# Batch 79 - 0.033363
# Batch 80 - 0.151614
# Batch 81 - 0.127117
# Batch 82 - 0.195629
# Batch 83 - 0.058964
# Batch 84 - 0.056521
# Batch 85 - 0.190581
# Batch 86 - 0.090558
# Batch 87 - 0.063293
# Batch 88 - 0.085376
# Batch 89 - 0.136041
# Batch 90 - 0.101509
# Batch 91 - 0.212631
# Batch 92 - 0.055624
# Batch 93 - 0.092229
# Batch 94 - 0.101147
# Batch 95 - 0.082439
# Batch 96 - 0.094419
# Batch 97 - 0.115290
# Batch 98 - 0.157330
# Batch 99 - 0.116006
# Batch 100 - 0.152137
# Batch 101 - 0.143016
# Batch 102 - 0.113442
# Batch 103 - 0.103832
# Batch 104 - 0.138081
# Batch 105 - 0.043724
# Batch 106 - 0.091624
# Batch 107 - 0.135946
# Batch 108 - 0.114016
# Batch 109 - 0.088686
# Batch 110 - 0.087911
# Batch 111 - 0.082997
# Batch 112 - 0.069000
# Batch 113 - 0.057294
# Batch 114 - 0.071473
# Batch 115 - 0.076264
# Batch 116 - 0.099059
# Batch 117 - 0.075624
# Batch 118 - 0.047973
# Batch 119 - 0.151526
# Batch 120 - 0.038295
# Batch 121 - 0.086152
# Batch 122 - 0.064663
# Batch 123 - 0.098911
# Batch 124 - 0.093203
# Batch 125 - 0.112464
# Batch 126 - 0.074308
# Batch 127 - 0.155800
# Batch 128 - 0.111450
# Batch 129 - 0.105002
# Batch 130 - 0.036465
# Batch 131 - 0.104219
# Batch 132 - 0.131797
# Batch 133 - 0.060150
# Batch 134 - 0.127239
# Batch 135 - 0.039373
# Batch 136 - 0.085273
# Batch 137 - 0.062309
# Batch 138 - 0.056189
# Batch 139 - 0.042643
# Batch 140 - 0.068853
# Batch 141 - 0.126385
# Batch 142 - 0.146615
# Batch 143 - 0.068923
# Batch 144 - 0.044989
# Batch 145 - 0.131930
# Batch 146 - 0.124553
# Batch 147 - 0.092376
# Batch 148 - 0.085427
# Batch 149 - 0.084740
# Batch 150 - 0.104810
# Batch 151 - 0.114511
# Batch 152 - 0.048253
# Batch 153 - 0.104703
# Batch 154 - 0.090980
# Batch 155 - 0.086335
# Batch 156 - 0.074621
# Batch 157 - 0.080595
# Batch 158 - 0.099027
# Batch 159 - 0.101321
# Batch 160 - 0.078761
# Batch 161 - 0.072739
# Batch 162 - 0.138419
# Batch 163 - 0.087431
# Batch 164 - 0.158875
# Batch 165 - 0.098429
# Batch 166 - 0.135701
# Batch 167 - 0.104313
# Batch 168 - 0.098418
# Batch 169 - 0.123938
# Batch 170 - 0.044353
# Batch 171 - 0.114303
# Batch 172 - 0.110500
# Batch 173 - 0.054881
# Batch 174 - 0.062812
# Batch 175 - 0.135125
# Batch 176 - 0.168982
# Batch 177 - 0.118691
# Batch 178 - 0.032650
# Batch 179 - 0.075289
# Batch 180 - 0.152071
# Batch 181 - 0.065257
# Batch 182 - 0.106531
# Batch 183 - 0.105916
# Batch 184 - 0.030212
# Batch 185 - 0.171177
# Batch 186 - 0.034196
# Batch 187 - 0.090957
# Batch 188 - 0.088946
# Batch 189 - 0.052170
# Batch 190 - 0.172271
# Batch 191 - 0.165075
# Batch 192 - 0.059927
# Batch 193 - 0.162348
# Batch 194 - 0.064298
# Batch 195 - 0.077013
# Batch 196 - 0.111707
# Batch 197 - 0.039428
# Batch 198 - 0.090550
# Batch 199 - 0.080997
# Batch 200 - 0.087133
# Batch 201 - 0.070596
# Batch 202 - 0.109844
# Batch 203 - 0.091134
# Batch 204 - 0.038752
# Batch 205 - 0.096303
# Batch 206 - 0.042282
# Batch 207 - 0.094717
# Batch 208 - 0.142347
# Batch 209 - 0.080714
# Batch 210 - 0.068819
# Batch 211 - 0.148149
# Batch 212 - 0.079105
# Batch 213 - 0.090209
# Batch 214 - 0.089992
# Batch 215 - 0.045172
# Batch 216 - 0.094825
# Batch 217 - 0.050724
# Batch 218 - 0.102141
# Batch 219 - 0.113047
# Batch 220 - 0.119627
# Batch 221 - 0.078075
# Batch 222 - 0.099043
# Batch 223 - 0.046116
# Batch 224 - 0.114604
# Batch 225 - 0.130230
# Batch 226 - 0.084613
# Batch 227 - 0.083648
# Batch 228 - 0.101258
# Batch 229 - 0.109499
# Batch 230 - 0.110565
# Batch 231 - 0.124471
# Batch 232 - 0.094768
# Batch 233 - 0.065235
# Batch 234 - 0.087902
# Batch 235 - 0.114009
# Batch 236 - 0.152653
# Batch 237 - 0.105708
# Batch 238 - 0.077685
# Batch 239 - 0.070578
# Batch 240 - 0.071372
# Batch 241 - 0.108851
# Batch 242 - 0.078093
# Batch 243 - 0.133145
# Batch 244 - 0.073436
# Batch 245 - 0.095691
# Batch 246 - 0.082732
# Batch 247 - 0.077971
# Batch 248 - 0.088921
# Batch 249 - 0.140558
# Batch 250 - 0.113840
# Batch 251 - 0.091486
# Batch 252 - 0.066441
# Batch 253 - 0.073392
# Batch 254 - 0.075464
# Batch 255 - 0.107940
# Batch 256 - 0.119552
# Batch 257 - 0.124565
# Batch 258 - 0.133292
# Batch 259 - 0.052773
# Batch 260 - 0.049882
# Batch 261 - 0.060181
# Batch 262 - 0.040781
# Batch 263 - 0.103134
# Batch 264 - 0.085432
# Batch 265 - 0.116016
# Batch 266 - 0.093721
# Batch 267 - 0.028433
# Batch 268 - 0.137642
# Batch 269 - 0.150321
# Batch 270 - 0.052564
# Batch 271 - 0.076961
# Batch 272 - 0.094730
# Batch 273 - 0.046324
# Batch 274 - 0.111718
# Batch 275 - 0.065916
# Batch 276 - 0.080077
# Batch 277 - 0.134033
# Batch 278 - 0.065897
# Batch 279 - 0.091310
# Batch 280 - 0.091405
# Batch 281 - 0.027494
#
# Overall weighted average distance across all adversarial samples: 0.093792

# %%
summarize_feature_changes(original_df=df_to_attack, adversarial_df=adversarial_df_GBT, features=all_features)
# Out:
# === Adversarial Change Summary ===
#
# Total datapoints: 8968
# Attempted attacks (on correct predictions): 7434
# Successful attacks (prediction flipped):    2899
# Success rate: 39.00%
# Total number of feature-level changes:      11656
#
# === Feature-Level Change Stats ===
#
# age:
#   - Changed in 1267 rows (43.70% of successful attacks)
#   - Fraction of total changes: 10.87%
#
# educational-num:
#   - Changed in 942 rows (32.49% of successful attacks)
#   - Fraction of total changes: 8.08%
#
# capital-gain:
#   - Changed in 808 rows (27.87% of successful attacks)
#   - Fraction of total changes: 6.93%
#
# capital-loss:
#   - Changed in 1131 rows (39.01% of successful attacks)
#   - Fraction of total changes: 9.70%
#
# hours-per-week:
#   - Changed in 908 rows (31.32% of successful attacks)
#   - Fraction of total changes: 7.79%
#
# workclass:
#   - Changed in 588 rows (20.28% of successful attacks)
#   - Fraction of total changes: 5.04%
#
# education:
#   - Changed in 1176 rows (40.57% of successful attacks)
#   - Fraction of total changes: 10.09%
#
# marital-status:
#   - Changed in 886 rows (30.56% of successful attacks)
#   - Fraction of total changes: 7.60%
#
# occupation:
#   - Changed in 579 rows (19.97% of successful attacks)
#   - Fraction of total changes: 4.97%
#
# relationship:
#   - Changed in 700 rows (24.15% of successful attacks)
#   - Fraction of total changes: 6.01%
#
# race:
#   - Changed in 305 rows (10.52% of successful attacks)
#   - Fraction of total changes: 2.62%
#
# gender:
#   - Changed in 211 rows (7.28% of successful attacks)
#   - Fraction of total changes: 1.81%
#
# native-country:
#   - Changed in 2155 rows (74.34% of successful attacks)
#   - Fraction of total changes: 18.49%

# %%
display_attacks(original_df=df_to_attack, adversarial_df=adversarial_df_GBT, correlation_dict=correlation_dict, all_features=all_features, n=5)
# Out:
# === Attack #1 ===
# Original:
# age                                46
# educational-num                    11
# capital-gain                        0
# capital-loss                        0
# hours-per-week                     40
# workclass                     Private
# education                   Assoc-voc
# marital-status     Married-civ-spouse
# occupation               Craft-repair
# relationship                  Husband
# race                            Black
# gender                           Male
# native-country          United-States
# Name: 4, dtype: object
#
# Adversarial:
# age                                    51
# educational-num                        12
# capital-gain                            0
# capital-loss                            0
# hours-per-week                         40
# workclass                         Private
# education                       Preschool
# marital-status         Married-civ-spouse
# occupation                   Craft-repair
# relationship                      Husband
# race                   Amer-Indian-Eskimo
# gender                               Male
# native-country                El-Salvador
# original_label                          1
# original_prediction                     1
# final_prediction                        0
# Name: 4, dtype: object
#
# Changed features:
# ['age', 'educational-num', 'education', 'race', 'native-country']
#
# Distance score: 0.106437
#
# === Attack #2 ===
# Original:
# age                           42
# educational-num                9
# capital-gain                   0
# capital-loss                   0
# hours-per-week                45
# workclass                Private
# education                HS-grad
# marital-status          Divorced
# occupation          Craft-repair
# relationship           Unmarried
# race                       Black
# gender                      Male
# native-country     United-States
# Name: 12, dtype: object
#
# Adversarial:
# age                                 42
# educational-num                      9
# capital-gain                         0
# capital-loss                      1564
# hours-per-week                      44
# workclass                      Private
# education                      HS-grad
# marital-status               Separated
# occupation             Priv-house-serv
# relationship             Not-in-family
# race                             Other
# gender                            Male
# native-country           United-States
# original_label                       0
# original_prediction                  0
# final_prediction                     1
# Name: 12, dtype: object
#
# Changed features:
# ['capital-loss', 'hours-per-week', 'marital-status', 'occupation', 'relationship', 'race']
#
# Distance score: 0.232330
#
# === Attack #3 ===
# Original:
# age                                48
# educational-num                    13
# capital-gain                        0
# capital-loss                        0
# hours-per-week                     40
# workclass                     Private
# education                   Bachelors
# marital-status     Married-civ-spouse
# occupation                      Sales
# relationship                  Husband
# race                            Black
# gender                           Male
# native-country          United-States
# Name: 15, dtype: object
#
# Adversarial:
# age                                    46
# educational-num                        13
# capital-gain                            0
# capital-loss                         1579
# hours-per-week                         39
# workclass                         Private
# education                       Bachelors
# marital-status         Married-civ-spouse
# occupation                          Sales
# relationship                      Husband
# race                                Other
# gender                               Male
# native-country                       Laos
# original_label                          1
# original_prediction                     1
# final_prediction                        0
# Name: 15, dtype: object
#
# Changed features:
# ['age', 'capital-loss', 'hours-per-week', 'race', 'native-country']
#
# Distance score: 0.176554
#
# === Attack #4 ===
# Original:
# age                                32
# educational-num                    11
# capital-gain                        0
# capital-loss                        0
# hours-per-week                     24
# workclass                     Private
# education                   Assoc-voc
# marital-status     Married-civ-spouse
# occupation               Tech-support
# relationship                     Wife
# race                            White
# gender                         Female
# native-country          United-States
# Name: 18, dtype: object
#
# Adversarial:
# age                                    32
# educational-num                        11
# capital-gain                         1086
# capital-loss                            0
# hours-per-week                         24
# workclass                         Private
# education                       Assoc-voc
# marital-status         Married-civ-spouse
# occupation                   Tech-support
# relationship               Other-relative
# race                                White
# gender                             Female
# native-country              United-States
# original_label                          1
# original_prediction                     1
# final_prediction                        0
# Name: 18, dtype: object
#
# Changed features:
# ['capital-gain', 'relationship']
#
# Distance score: 0.353189
#
# === Attack #5 ===
# Original:
# age                                39
# educational-num                    13
# capital-gain                        0
# capital-loss                     1848
# hours-per-week                     40
# workclass                     Private
# education                   Bachelors
# marital-status     Married-civ-spouse
# occupation                      Sales
# relationship                  Husband
# race                            White
# gender                           Male
# native-country          United-States
# Name: 19, dtype: object
#
# Adversarial:
# age                                    38
# educational-num                        14
# capital-gain                            0
# capital-loss                         1741
# hours-per-week                         40
# workclass                         Private
# education                         Masters
# marital-status         Married-civ-spouse
# occupation                   Tech-support
# relationship                      Husband
# race                                White
# gender                               Male
# native-country                      Japan
# original_label                          1
# original_prediction                     1
# final_prediction                        0
# Name: 19, dtype: object
#
# Changed features:
# ['age', 'educational-num', 'capital-loss', 'education', 'occupation', 'native-country']
#
# Distance score: 0.100825

# %%
compare_attack_results(df_to_attack, adversarial_df_GBT)
# Out:
# === Model Performance Comparison ===
# Original Accuracy:  0.8289 | Attacked Accuracy:  0.5057
# Original Precision: 0.8187 | Attacked Precision: 0.5080
# Original Recall:    0.8450 | Attacked Recall:    0.3615
# Original F1-Score:  0.8317 | Attacked F1-Score:  0.4224
#
#  Accuracy Drop due to Attack: 0.3233 (32.33% decrease)

# %%
plot_roc_comparison(df_attacked=adversarial_df_GBT,
                    label_col='original_label',
                    original_score_col='score_before_attack',
                    attacked_score_col='score_after_attack')

# %%
plot_pca_projection(
    df_original=df_to_attack,
    df_attacked=adversarial_df_GBT,
    encoders=encoders,
    title_prefix='GBT '
)

# %%
plot_adversarial_shift_arrows(
    df_original=df_to_attack,
    df_attacked=adversarial_df_GBT,
    encoders=encoders,
    title_prefix='GBT '
)

# %% [markdown]
# ## 4.2 LLM Evaluation

# %%
print_weighted_correlation_summary(distances_LLM, batch_sizes_LLM)
# Out:
# Total number of batches: 281
#
# Final correlation distance from original samples:
# Batch 1 - 0.082751
# Batch 2 - 0.039938
# Batch 3 - 0.077724
# Batch 4 - 0.137459
# Batch 5 - 0.048455
# Batch 6 - 0.038074
# Batch 7 - 0.113260
# Batch 8 - 0.117625
# Batch 9 - 0.106903
# Batch 10 - 0.115401
# Batch 11 - 0.113223
# Batch 12 - 0.112047
# Batch 13 - 0.136819
# Batch 14 - 0.103039
# Batch 15 - 0.081099
# Batch 16 - 0.079854
# Batch 17 - 0.107285
# Batch 18 - 0.063440
# Batch 19 - 0.063174
# Batch 20 - 0.068618
# Batch 21 - 0.046093
# Batch 22 - 0.081910
# Batch 23 - 0.103991
# Batch 24 - 0.050636
# Batch 25 - 0.091216
# Batch 26 - 0.041939
# Batch 27 - 0.131072
# Batch 28 - 0.111973
# Batch 29 - 0.101700
# Batch 30 - 0.045365
# Batch 31 - 0.073386
# Batch 32 - 0.110991
# Batch 33 - 0.028684
# Batch 34 - 0.072382
# Batch 35 - 0.083129
# Batch 36 - 0.069196
# Batch 37 - 0.104157
# Batch 38 - 0.061269
# Batch 39 - 0.141114
# Batch 40 - 0.090044
# Batch 41 - 0.065903
# Batch 42 - 0.050886
# Batch 43 - 0.161330
# Batch 44 - 0.113151
# Batch 45 - 0.094948
# Batch 46 - 0.085634
# Batch 47 - 0.136175
# Batch 48 - 0.126764
# Batch 49 - 0.086625
# Batch 50 - 0.097598
# Batch 51 - 0.085194
# Batch 52 - 0.180264
# Batch 53 - 0.072147
# Batch 54 - 0.108048
# Batch 55 - 0.066587
# Batch 56 - 0.103161
# Batch 57 - 0.044794
# Batch 58 - 0.116976
# Batch 59 - 0.067054
# Batch 60 - 0.162701
# Batch 61 - 0.073593
# Batch 62 - 0.036006
# Batch 63 - 0.072406
# Batch 64 - 0.124043
# Batch 65 - 0.118518
# Batch 66 - 0.135522
# Batch 67 - 0.130659
# Batch 68 - 0.024777
# Batch 69 - 0.140167
# Batch 70 - 0.111781
# Batch 71 - 0.134627
# Batch 72 - 0.059991
# Batch 73 - 0.120393
# Batch 74 - 0.065438
# Batch 75 - 0.032393
# Batch 76 - 0.105834
# Batch 77 - 0.062566
# Batch 78 - 0.102218
# Batch 79 - 0.033363
# Batch 80 - 0.151614
# Batch 81 - 0.127117
# Batch 82 - 0.195629
# Batch 83 - 0.058964
# Batch 84 - 0.056521
# Batch 85 - 0.190581
# Batch 86 - 0.090558
# Batch 87 - 0.063293
# Batch 88 - 0.085376
# Batch 89 - 0.136041
# Batch 90 - 0.101509
# Batch 91 - 0.212631
# Batch 92 - 0.055624
# Batch 93 - 0.092229
# Batch 94 - 0.101147
# Batch 95 - 0.082439
# Batch 96 - 0.094419
# Batch 97 - 0.115290
# Batch 98 - 0.157330
# Batch 99 - 0.116006
# Batch 100 - 0.152137
# Batch 101 - 0.143016
# Batch 102 - 0.113442
# Batch 103 - 0.103832
# Batch 104 - 0.138081
# Batch 105 - 0.043724
# Batch 106 - 0.091624
# Batch 107 - 0.135946
# Batch 108 - 0.114016
# Batch 109 - 0.088686
# Batch 110 - 0.087911
# Batch 111 - 0.082997
# Batch 112 - 0.069000
# Batch 113 - 0.057294
# Batch 114 - 0.071473
# Batch 115 - 0.076264
# Batch 116 - 0.099059
# Batch 117 - 0.075624
# Batch 118 - 0.047973
# Batch 119 - 0.151526
# Batch 120 - 0.038295
# Batch 121 - 0.086152
# Batch 122 - 0.064663
# Batch 123 - 0.098911
# Batch 124 - 0.093203
# Batch 125 - 0.112464
# Batch 126 - 0.074308
# Batch 127 - 0.155800
# Batch 128 - 0.111450
# Batch 129 - 0.105002
# Batch 130 - 0.036465
# Batch 131 - 0.104219
# Batch 132 - 0.131797
# Batch 133 - 0.060150
# Batch 134 - 0.127239
# Batch 135 - 0.039373
# Batch 136 - 0.085273
# Batch 137 - 0.062309
# Batch 138 - 0.056189
# Batch 139 - 0.042643
# Batch 140 - 0.068853
# Batch 141 - 0.126385
# Batch 142 - 0.146615
# Batch 143 - 0.068923
# Batch 144 - 0.044989
# Batch 145 - 0.131930
# Batch 146 - 0.124553
# Batch 147 - 0.092376
# Batch 148 - 0.085427
# Batch 149 - 0.084740
# Batch 150 - 0.104810
# Batch 151 - 0.114511
# Batch 152 - 0.048253
# Batch 153 - 0.104703
# Batch 154 - 0.090980
# Batch 155 - 0.086335
# Batch 156 - 0.074621
# Batch 157 - 0.080595
# Batch 158 - 0.099027
# Batch 159 - 0.101321
# Batch 160 - 0.078761
# Batch 161 - 0.072739
# Batch 162 - 0.138419
# Batch 163 - 0.087431
# Batch 164 - 0.158875
# Batch 165 - 0.098429
# Batch 166 - 0.135701
# Batch 167 - 0.104313
# Batch 168 - 0.098418
# Batch 169 - 0.123938
# Batch 170 - 0.044353
# Batch 171 - 0.114303
# Batch 172 - 0.110500
# Batch 173 - 0.054881
# Batch 174 - 0.062812
# Batch 175 - 0.135125
# Batch 176 - 0.168982
# Batch 177 - 0.118691
# Batch 178 - 0.032650
# Batch 179 - 0.075289
# Batch 180 - 0.152071
# Batch 181 - 0.065257
# Batch 182 - 0.106531
# Batch 183 - 0.105916
# Batch 184 - 0.030212
# Batch 185 - 0.171177
# Batch 186 - 0.034196
# Batch 187 - 0.090957
# Batch 188 - 0.088946
# Batch 189 - 0.052170
# Batch 190 - 0.172271
# Batch 191 - 0.165075
# Batch 192 - 0.059927
# Batch 193 - 0.162348
# Batch 194 - 0.064298
# Batch 195 - 0.077013
# Batch 196 - 0.111707
# Batch 197 - 0.039428
# Batch 198 - 0.090550
# Batch 199 - 0.080997
# Batch 200 - 0.087133
# Batch 201 - 0.070596
# Batch 202 - 0.109844
# Batch 203 - 0.091134
# Batch 204 - 0.038752
# Batch 205 - 0.096303
# Batch 206 - 0.042282
# Batch 207 - 0.094717
# Batch 208 - 0.142347
# Batch 209 - 0.080714
# Batch 210 - 0.068819
# Batch 211 - 0.148149
# Batch 212 - 0.079105
# Batch 213 - 0.090209
# Batch 214 - 0.089992
# Batch 215 - 0.045172
# Batch 216 - 0.094825
# Batch 217 - 0.050724
# Batch 218 - 0.102141
# Batch 219 - 0.113047
# Batch 220 - 0.119627
# Batch 221 - 0.078075
# Batch 222 - 0.099043
# Batch 223 - 0.046116
# Batch 224 - 0.114604
# Batch 225 - 0.130230
# Batch 226 - 0.084613
# Batch 227 - 0.083648
# Batch 228 - 0.101258
# Batch 229 - 0.109499
# Batch 230 - 0.110565
# Batch 231 - 0.124471
# Batch 232 - 0.094768
# Batch 233 - 0.065235
# Batch 234 - 0.087902
# Batch 235 - 0.114009
# Batch 236 - 0.152653
# Batch 237 - 0.105708
# Batch 238 - 0.077685
# Batch 239 - 0.070578
# Batch 240 - 0.071372
# Batch 241 - 0.108851
# Batch 242 - 0.078093
# Batch 243 - 0.133145
# Batch 244 - 0.073436
# Batch 245 - 0.095691
# Batch 246 - 0.082732
# Batch 247 - 0.077971
# Batch 248 - 0.088921
# Batch 249 - 0.140558
# Batch 250 - 0.113840
# Batch 251 - 0.091486
# Batch 252 - 0.066441
# Batch 253 - 0.073392
# Batch 254 - 0.075464
# Batch 255 - 0.107940
# Batch 256 - 0.119552
# Batch 257 - 0.124565
# Batch 258 - 0.133292
# Batch 259 - 0.052773
# Batch 260 - 0.049882
# Batch 261 - 0.060181
# Batch 262 - 0.040781
# Batch 263 - 0.103134
# Batch 264 - 0.085432
# Batch 265 - 0.116016
# Batch 266 - 0.093721
# Batch 267 - 0.028433
# Batch 268 - 0.137642
# Batch 269 - 0.150321
# Batch 270 - 0.052564
# Batch 271 - 0.076961
# Batch 272 - 0.094730
# Batch 273 - 0.046324
# Batch 274 - 0.111718
# Batch 275 - 0.065916
# Batch 276 - 0.080077
# Batch 277 - 0.134033
# Batch 278 - 0.065897
# Batch 279 - 0.091310
# Batch 280 - 0.091405
# Batch 281 - 0.027494
#
# Overall weighted average distance across all adversarial samples: 0.093792

# %%
summarize_feature_changes(original_df=df_to_attack, adversarial_df=adversarial_df_LLM, features=all_features)
# Out:
# === Adversarial Change Summary ===
#
# Total datapoints: 8968
# Attempted attacks (on correct predictions): 7434
# Successful attacks (prediction flipped):    2899
# Success rate: 39.00%
# Total number of feature-level changes:      11656
#
# === Feature-Level Change Stats ===
#
# age:
#   - Changed in 1267 rows (43.70% of successful attacks)
#   - Fraction of total changes: 10.87%
#
# educational-num:
#   - Changed in 942 rows (32.49% of successful attacks)
#   - Fraction of total changes: 8.08%
#
# capital-gain:
#   - Changed in 808 rows (27.87% of successful attacks)
#   - Fraction of total changes: 6.93%
#
# capital-loss:
#   - Changed in 1131 rows (39.01% of successful attacks)
#   - Fraction of total changes: 9.70%
#
# hours-per-week:
#   - Changed in 908 rows (31.32% of successful attacks)
#   - Fraction of total changes: 7.79%
#
# workclass:
#   - Changed in 588 rows (20.28% of successful attacks)
#   - Fraction of total changes: 5.04%
#
# education:
#   - Changed in 1176 rows (40.57% of successful attacks)
#   - Fraction of total changes: 10.09%
#
# marital-status:
#   - Changed in 886 rows (30.56% of successful attacks)
#   - Fraction of total changes: 7.60%
#
# occupation:
#   - Changed in 579 rows (19.97% of successful attacks)
#   - Fraction of total changes: 4.97%
#
# relationship:
#   - Changed in 700 rows (24.15% of successful attacks)
#   - Fraction of total changes: 6.01%
#
# race:
#   - Changed in 305 rows (10.52% of successful attacks)
#   - Fraction of total changes: 2.62%
#
# gender:
#   - Changed in 211 rows (7.28% of successful attacks)
#   - Fraction of total changes: 1.81%
#
# native-country:
#   - Changed in 2155 rows (74.34% of successful attacks)
#   - Fraction of total changes: 18.49%

# %%
display_attacks(original_df=df_to_attack, adversarial_df=adversarial_df_LLM, correlation_dict=correlation_dict, all_features=all_features, n=5)
# Out:
# === Attack #1 ===
# Original:
# age                                46
# educational-num                    11
# capital-gain                        0
# capital-loss                        0
# hours-per-week                     40
# workclass                     Private
# education                   Assoc-voc
# marital-status     Married-civ-spouse
# occupation               Craft-repair
# relationship                  Husband
# race                            Black
# gender                           Male
# native-country          United-States
# Name: 4, dtype: object
#
# Adversarial:
# age                                    51
# educational-num                        12
# capital-gain                            0
# capital-loss                            0
# hours-per-week                         40
# workclass                         Private
# education                       Preschool
# marital-status         Married-civ-spouse
# occupation                   Craft-repair
# relationship                      Husband
# race                   Amer-Indian-Eskimo
# gender                               Male
# native-country                El-Salvador
# original_label                          1
# original_prediction                     1
# final_prediction                        0
# Name: 4, dtype: object
#
# Changed features:
# ['age', 'educational-num', 'education', 'race', 'native-country']
#
# Distance score: 0.106437
#
# === Attack #2 ===
# Original:
# age                           42
# educational-num                9
# capital-gain                   0
# capital-loss                   0
# hours-per-week                45
# workclass                Private
# education                HS-grad
# marital-status          Divorced
# occupation          Craft-repair
# relationship           Unmarried
# race                       Black
# gender                      Male
# native-country     United-States
# Name: 12, dtype: object
#
# Adversarial:
# age                                 42
# educational-num                      9
# capital-gain                         0
# capital-loss                      1564
# hours-per-week                      44
# workclass                      Private
# education                      HS-grad
# marital-status               Separated
# occupation             Priv-house-serv
# relationship             Not-in-family
# race                             Other
# gender                            Male
# native-country           United-States
# original_label                       0
# original_prediction                  0
# final_prediction                     1
# Name: 12, dtype: object
#
# Changed features:
# ['capital-loss', 'hours-per-week', 'marital-status', 'occupation', 'relationship', 'race']
#
# Distance score: 0.232330
#
# === Attack #3 ===
# Original:
# age                                48
# educational-num                    13
# capital-gain                        0
# capital-loss                        0
# hours-per-week                     40
# workclass                     Private
# education                   Bachelors
# marital-status     Married-civ-spouse
# occupation                      Sales
# relationship                  Husband
# race                            Black
# gender                           Male
# native-country          United-States
# Name: 15, dtype: object
#
# Adversarial:
# age                                    46
# educational-num                        13
# capital-gain                            0
# capital-loss                         1579
# hours-per-week                         39
# workclass                         Private
# education                       Bachelors
# marital-status         Married-civ-spouse
# occupation                          Sales
# relationship                      Husband
# race                                Other
# gender                               Male
# native-country                       Laos
# original_label                          1
# original_prediction                     1
# final_prediction                        0
# Name: 15, dtype: object
#
# Changed features:
# ['age', 'capital-loss', 'hours-per-week', 'race', 'native-country']
#
# Distance score: 0.176554
#
# === Attack #4 ===
# Original:
# age                                32
# educational-num                    11
# capital-gain                        0
# capital-loss                        0
# hours-per-week                     24
# workclass                     Private
# education                   Assoc-voc
# marital-status     Married-civ-spouse
# occupation               Tech-support
# relationship                     Wife
# race                            White
# gender                         Female
# native-country          United-States
# Name: 18, dtype: object
#
# Adversarial:
# age                                    32
# educational-num                        11
# capital-gain                         1086
# capital-loss                            0
# hours-per-week                         24
# workclass                         Private
# education                       Assoc-voc
# marital-status         Married-civ-spouse
# occupation                   Tech-support
# relationship               Other-relative
# race                                White
# gender                             Female
# native-country              United-States
# original_label                          1
# original_prediction                     1
# final_prediction                        0
# Name: 18, dtype: object
#
# Changed features:
# ['capital-gain', 'relationship']
#
# Distance score: 0.353189
#
# === Attack #5 ===
# Original:
# age                                39
# educational-num                    13
# capital-gain                        0
# capital-loss                     1848
# hours-per-week                     40
# workclass                     Private
# education                   Bachelors
# marital-status     Married-civ-spouse
# occupation                      Sales
# relationship                  Husband
# race                            White
# gender                           Male
# native-country          United-States
# Name: 19, dtype: object
#
# Adversarial:
# age                                    38
# educational-num                        14
# capital-gain                            0
# capital-loss                         1741
# hours-per-week                         40
# workclass                         Private
# education                         Masters
# marital-status         Married-civ-spouse
# occupation                   Tech-support
# relationship                      Husband
# race                                White
# gender                               Male
# native-country                      Japan
# original_label                          1
# original_prediction                     1
# final_prediction                        0
# Name: 19, dtype: object
#
# Changed features:
# ['age', 'educational-num', 'capital-loss', 'education', 'occupation', 'native-country']
#
# Distance score: 0.100825

# %%
compare_attack_results(df_to_attack, adversarial_df_LLM)
# Out:
# === Model Performance Comparison ===
# Original Accuracy:  0.8289 | Attacked Accuracy:  0.5057
# Original Precision: 0.8187 | Attacked Precision: 0.5080
# Original Recall:    0.8450 | Attacked Recall:    0.3615
# Original F1-Score:  0.8317 | Attacked F1-Score:  0.4224
#
#  Accuracy Drop due to Attack: 0.3233 (32.33% decrease)

# %%
plot_roc_comparison(df_attacked=adversarial_df_LLM,
                    label_col='original_label',
                    original_score_col='score_before_attack',
                    attacked_score_col='score_after_attack')

# %%
plot_pca_projection(
    df_original=df_to_attack,
    df_attacked=adversarial_df_LLM,
    encoders=encoders,
    title_prefix='RoBERTa'
)

# %%
plot_adversarial_shift_arrows(
    df_original=df_to_attack,
    df_attacked=adversarial_df_LLM,
    encoders=encoders,
    title_prefix='RoBERTa '
)
